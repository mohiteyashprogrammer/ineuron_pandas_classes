# %%
import pandas as pd
import numpy as np
import seaborn as sns
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %matplotlib inline

# %%
data = sns.load_dataset("penguins")

# %%
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.relplot(x = "flipper_length_mm", y = "body_mass_g",hue = "sex",data=data)

# %%
sns.relplot(x = "bill_length_mm", y = "body_mass_g",hue = "sex",data=data)

# %%
sns.relplot(x = "flipper_length_mm", y = "body_mass_g",hue = "sex",style = "species",data=data)

# %%
sns.relplot(x = "flipper_length_mm", y = "body_mass_g",hue = "species",data=data)

# %%
sns.relplot(x = "flipper_length_mm", y = "body_mass_g",hue = "island",data=data)

# %%
sns.relplot(x = "flipper_length_mm", y = "body_mass_g",hue = "island",style = "sex",data=data)

# %%
df = sns.load_dataset("car_crashes")

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x = "alcohol",y = "speeding",data=df)

# %%
sns.relplot(x = "alcohol",y = "speeding",hue = "not_distracted",data=df)

# %%
sns.relplot(x = "alcohol",y = "speeding",data=df)

# %%
# pandas plot
i = df.iloc[2,[0,1,2,3,4,5,6]]

# %%
i.plot.pie(figsize = (10,20))
# Out:
# <AxesSubplot:ylabel='2'>

# %%
i.plot.bar()
# Out:
# <AxesSubplot:>
