# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\yash mohite\OneDrive\Desktop\netflix recommendation system\netflix_titles.csv")

# %%
data.to_csv("movie_series",index=False)

# %%
data = pd.read_csv("movie_series")

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
list(data.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %%
data.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
#
# ...

# %%
# how many movie are there in this data set
len(data[data["type"] == "Movie"])
# Out:
# 6131

# %%
# how many Tv.series are there in this data set
len(data[data["type"] == "TV Show"])
# Out:
# 2676

# %%
# How many movies from USA
len(data[(data["type"] == "Movie") & (data["country"] == "United States")])
# Out:
# 2058

# %%
# How many movies from india
len(data[(data["type"] == "Movie") & (data["country"] == "India")])
# Out:
# 893

# %%
# How many movies from india china
len(data[(data["type"] == "Movie") & (data["country"] == "China")])
# Out:
# 28

# %%
# How many movies from india japan
len(data[(data["type"] == "Movie") & (data["country"] == "Japan")])
# Out:
# 76

# %%
# How many series from USA
len(data[(data["type"] == "TV Show") & (data["country"] == "United States")])
# Out:
# 760

# %%
# How many series from India
len(data[(data["type"] == "TV Show") & (data["country"] == "India")])
# Out:
# 79

# %%
# How many series from japan
len(data[(data["type"] == "TV Show") & (data["country"] == "Japan")])
# Out:
# 169

# %%
# how many movies relesed in 2018
len(data[(data["type"] == "Movie") & (data["release_year"] == 2018)])
# Out:
# 767

# %%
# how many movies relesed in 2019
len(data[(data["type"] == "Movie") & (data["release_year"] == 2019)])
# Out:
# 633

# %%
# how many movies relesed in 2020
len(data[(data["type"] == "Movie") & (data["release_year"] == 2020)])
# Out:
# 517

# %%
# how many series relesed in 2018
len(data[(data["type"] == "TV Show") & (data["release_year"] == 2018)])
# Out:
# 380

# %%
# how many series relesed in 2019
len(data[(data["type"] == "TV Show") & (data["release_year"] == 2019)])
# Out:
# 397

# %%
# how many series relesed in 2020
len(data[(data["type"] == "TV Show") & (data["release_year"] == 2020)])
# Out:
# 436

# %%
# how many series relesed in 2021
len(data[(data["type"] == "TV Show") & (data["release_year"] == 2021)])
# Out:
# 315

# %%
# how many movie are relased in japan in 2020
len(data[(data["type"] == "Movie") & (data["release_year"] == 2020) & (data["country"] == "Japan")])
# Out:
# 7

# %%
# how many Series are relased in japan in 2020
len(data[(data["type"] == "TV Show") & (data["release_year"] == 2020) & (data["country"] == "Japan")])
# Out:
# 13

# %%
# how many series are relesed in india in 2020
len(data[(data["type"] == "TV Show") & (data["release_year"] == 2020) & (data["country"] == "India")])
# Out:
# 16

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# how many movies are pg-13 
len(data[(data["type"] == "Movie") & (data["rating"] == "PG-13")])
# Out:
# 490

# %%
# how many movies are R-Rated
len(data[(data["type"] == "Movie") & (data["rating"] == "R")])
# Out:
# 797

# %%
# how many series sare Rrated 
data[(data["type"] == "TV Show") & (data["rating"] == "R")]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 3893  Trapped at a stagecoach stop as a storm rages ...
# 7593  A series of incidents in Afghanistan set compl...

# %%
# fetch the documentry movies and ratings

# %%
data[(data["type"] == "Movie") & (data["rating"] == "R") & (data["listed_in"] == "Documentaries")]
# Out:
#      show_id   type                                              title  \
# 1195   s1196  Movie  Operation Varsity Blues: The College Admission...
# 1343   s1344  Movie                                Strip Down, Rise Up
# 1690   s1691  Movie                                     Whose Streets?
# 2228   s2229  Movie                                 Father Soldier Son
# 2779   s2780  Movie                 Crip Camp: A Disability Revolution
# 5116   s5117  Movie               Jeremiah Tower: The Last Magnificent
# 5179   s5180  Movie                           Jerry Seinfeld: Comedian
# 5197   s5198  Movie    The B-Side: Elsa Dorfman's Portrait Photography
# 6104   s6105  Movie                             Ai Weiwei: Never Sorry
# 6545   s6546  Movie                                Cutie and the Boxer
# 6575   s6576  Movie                                           De Palma
# 6799   s6800  Movie                       Freeway: Crack in the System
# ...

# %%
# fatch all movies of Ruben Fleischer
data[(data["type"] == "Movie") & (data["director"] == "Ruben Fleischer")]
# Out:
#      show_id   type               title         director  \
# 6012   s6013  Movie  30 Minutes or Less  Ruben Fleischer
# 8804   s8805  Movie          Zombieland  Ruben Fleischer
#
#                                                    cast        country  \
# 6012  Jesse Eisenberg, Danny McBride, Aziz Ansari, N...  United States
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
#
#             date_added  release_year rating duration  \
# 6012   January 1, 2021          2011      R   83 min
# 8804  November 1, 2019          2009      R   88 min
#
#                          listed_in  \
# 6012  Action & Adventure, Comedies
# 8804       Comedies, Horror Movies
#
#                                             description
# 6012  Two crooks planning a bank heist wind up abduc...
# 8804  Looking to survive in a world taken over by zo...

# %%
# fatch the movie of Rajiv Chilaka
data[(data["type"] == "Movie") & (data["director"] == "Rajiv Chilaka")]
# Out:
#      show_id   type                                              title  \
# 406     s407  Movie                       Chhota Bheem - Neeli Pahaadi
# 407     s408  Movie                              Chhota Bheem & Ganesh
# 408     s409  Movie                 Chhota Bheem & Krishna: Mayanagari
# 409     s410  Movie  Chhota Bheem & Krishna: Pataliputra- City of t...
# 410     s411  Movie                 Chhota Bheem And The Broken Amulet
# 411     s412  Movie             Chhota Bheem And The Crown of Valhalla
# 412     s413  Movie               Chhota Bheem and the Incan Adventure
# 413     s414  Movie                Chhota Bheem and The ShiNobi Secret
# 414     s415  Movie                           Chhota Bheem Aur Hanuman
# 415     s416  Movie                           Chhota Bheem aur Krishna
# 416     s417  Movie                Chhota Bheem aur Krishna vs Zimbara
# 419     s420  Movie                      Chhota Bheem: Bheem vs Aliens
# ...

# %%
# cast David Attenborough in which movie
data[(data["type"] == "Movie") & (data["cast"] == "David Attenborough")]
# Out:
#      show_id   type                                     title  \
# 1886   s1887  Movie  David Attenborough: A Life on Our Planet
# 3573   s3574  Movie            Our Planet - Behind The Scenes
# 6811   s6812  Movie                Frozen Planet: On Thin Ice
# 6812   s6813  Movie           Frozen Planet: The Epic Journey
# 7570   s7571  Movie        Nature: Raising the Dinosaur Giant
#
#                                                director                cast  \
# 1886  Alastair Fothergill, Jonnie Hughes, Keith Scholey  David Attenborough
# 3573                                                NaN  David Attenborough
# 6811                                                NaN  David Attenborough
# 6812                                                NaN  David Attenborough
# 7570                                                NaN  David Attenborough
#
#                                                 country        date_added  \
# ...

# %%
data["title"] = data["title"].apply(lambda x: x.replace(" ",""))

# %%
data.head()
# Out:
#   show_id     type                title         director  \
# 0      s1    Movie    DickJohnsonIsDead  Kirsten Johnson
# 1      s2  TV Show          Blood&Water              NaN
# 2      s3  TV Show            Ganglands  Julien Leclercq
# 3      s4  TV Show  JailbirdsNewOrleans              NaN
# 4      s5  TV Show          KotaFactory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data["id"] = data["show_id"]

# %%
data.head(2)
# Out:
#   show_id     type              title         director  \
# 0      s1    Movie  DickJohnsonIsDead  Kirsten Johnson
# 1      s2  TV Show        Blood&Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  id
# 0  As her father nears the end of his life, filmm...  s1
# 1  After crossing paths at a party, a Cape Town t...  s2

# %%
data["movie_time"] = data["type"] + data["duration"]

# %%
data.head(2)
# Out:
#   show_id     type              title         director  \
# 0      s1    Movie  DickJohnsonIsDead  Kirsten Johnson
# 1      s2  TV Show        Blood&Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  id        movie_time
# 0  As her father nears the end of his life, filmm...  s1       Movie90 min
# 1  After crossing paths at a party, a Cape Town t...  s2  TV Show2 Seasons

# %%
data.drop("movie_time",axis=1,inplace=True)

# %%
data.drop("id",axis=1,inplace=True)

# %%
data.head(2)
# Out:
#   show_id     type              title         director  \
# 0      s1    Movie  DickJohnsonIsDead  Kirsten Johnson
# 1      s2  TV Show        Blood&Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data.drop(1)
# Out:
#      show_id     type                title         director  \
# 0         s1    Movie    DickJohnsonIsDead  Kirsten Johnson
# 2         s3  TV Show            Ganglands  Julien Leclercq
# 3         s4  TV Show  JailbirdsNewOrleans              NaN
# 4         s5  TV Show          KotaFactory              NaN
# 5         s6  TV Show         MidnightMass    Mike Flanagan
# ...      ...      ...                  ...              ...
# 8802   s8803    Movie               Zodiac    David Fincher
# 8803   s8804  TV Show           ZombieDumb              NaN
# 8804   s8805    Movie           Zombieland  Ruben Fleischer
# 8805   s8806    Movie                 Zoom     Peter Hewitt
# 8806   s8807    Movie               Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
data.iloc[1]
# Out:
# show_id                                                        s2
# type                                                      TV Show
# title                                                 Blood&Water
# director                                                      NaN
# cast            Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# country                                              South Africa
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in         International TV Shows, TV Dramas, TV Mysteries
# description     After crossing paths at a party, a Cape Town t...
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# show_id                                                        s2
# type                                                      TV Show
# title                                                 Blood&Water
# director                                                      NaN
# cast            Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# country                                              South Africa
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in         International TV Shows, TV Dramas, TV Mysteries
# description     After crossing paths at a party, a Cape Town t...
# Name: 1, dtype: object

# %%
data.loc[8000:8002]
# Out:
#      show_id     type       title                   director  \
# 8000   s8001    Movie  SheDidThat                        NaN
# 8001   s8002    Movie     Shelter  Måns Mårlind, Björn Stein
# 8002   s8003  TV Show    Sherlock                        NaN
#
#                                                    cast  \
# 8000  Luvvie Ajayi, Renae Bluitt, Melissa Butler, Li...
# 8001  Julianne Moore, Jonathan Rhys Meyers, Jeffrey ...
# 8002  Benedict Cumberbatch, Martin Freeman, Una Stub...
#
#                             country         date_added  release_year rating  \
# 8000                  United States   February 4, 2020          2019  TV-PG
# 8001                  United States  December 29, 2017          2010      R
# 8002  United Kingdom, United States       May 15, 2017          2017  TV-14
#
#        duration                                          listed_in  \
# 8000     71 min                                      Documentaries
# ...

# %%
data.loc[8000:8002,["title","cast"]]
# Out:
#            title                                               cast
# 8000  SheDidThat  Luvvie Ajayi, Renae Bluitt, Melissa Butler, Li...
# 8001     Shelter  Julianne Moore, Jonathan Rhys Meyers, Jeffrey ...
# 8002    Sherlock  Benedict Cumberbatch, Martin Freeman, Una Stub...

# %%
data.loc[[1,5],["title","cast"]]
# Out:
#           title                                               cast
# 1   Blood&Water  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 5  MidnightMass  Kate Siegel, Zach Gilford, Hamish Linklater, H...

# %%
data.iloc[1:5,[3,4]]
# Out:
#           director                                               cast
# 1              NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3              NaN                                                NaN
# 4              NaN  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...

# %%
data.iloc[[10,8000],[2,1]]
# Out:
#                                title     type
# 10    Vendetta:Truth,LiesandTheMafia  TV Show
# 8000                      SheDidThat    Movie

# %%
data.head()
# Out:
#   show_id     type                title         director  \
# 0      s1    Movie    DickJohnsonIsDead  Kirsten Johnson
# 1      s2  TV Show          Blood&Water              NaN
# 2      s3  TV Show            Ganglands  Julien Leclercq
# 3      s4  TV Show  JailbirdsNewOrleans              NaN
# 4      s5  TV Show          KotaFactory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
list(data.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
df = data.loc[1:20,['director','cast','country','release_year']]

# %%
df
# Out:
#                                          director  \
# 1                                             NaN
# 2                                 Julien Leclercq
# 3                                             NaN
# 4                                             NaN
# 5                                   Mike Flanagan
# 6                   Robert Cullen, José Luis Ucha
# 7                                    Haile Gerima
# 8                                 Andy Devonshire
# 9                                  Theodore Melfi
# 10                                            NaN
# 11                              Kongkiat Komesiri
# 12                            Christian Schwochow
# 13                                  Bruno Garotti
# 14                                            NaN
# 15                                            NaN
# 16  Pedro de Echave García, Pablo Azorín Williams
# 17                                            NaN
# 18                                     Adam Salky
# ...

# %%
df.dropna(axis=1)
# Out:
#     release_year
# 1           2021
# 2           2021
# 3           2021
# 4           2021
# 5           2021
# 6           2021
# 7           1993
# 8           2021
# 9           2021
# 10          2021
# 11          2021
# 12          2021
# 13          2021
# 14          2021
# 15          2021
# 16          2020
# 17          2020
# 18          2021
# 19          2021
# 20          2021

# %%
df.dropna(axis=0)
# Out:
#                director                                               cast  \
# 7          Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8       Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9        Theodore Melfi  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Christian Schwochow  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country  release_year
# 7   United States, Ghana, Burkina Faso, United Kin...          1993
# 8                                      United Kingdom          2021
# 9                                       United States          2021
# 12                            Germany, Czech Republic          2021

# %%
df.fillna(147)
# Out:
#                                          director  \
# 1                                             147
# 2                                 Julien Leclercq
# 3                                             147
# 4                                             147
# 5                                   Mike Flanagan
# 6                   Robert Cullen, José Luis Ucha
# 7                                    Haile Gerima
# 8                                 Andy Devonshire
# 9                                  Theodore Melfi
# 10                                            147
# 11                              Kongkiat Komesiri
# 12                            Christian Schwochow
# 13                                  Bruno Garotti
# 14                                            147
# 15                                            147
# 16  Pedro de Echave García, Pablo Azorín Williams
# 17                                            147
# 18                                     Adam Salky
# ...

# %%
df.groupby("release_year").sum()
# Out:
#                                                        director  \
# release_year
# 1993                                               Haile Gerima
# 2020              Pedro de Echave García, Pablo Azorín Williams
# 2021          Julien LeclercqMike FlanaganRobert Cullen, Jos...
#
#                                                            cast  \
# release_year
# 1993          Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 2020          Luis Ernesto Franco, Camila Sodi, Sergio Goyri...
# 2021          Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
#
#                                                         country
# release_year
# 1993          United States, Ghana, Burkina Faso, United Kin...
# 2020                                                     Mexico
# 2021          South AfricaIndiaUnited KingdomUnited StatesGe...
