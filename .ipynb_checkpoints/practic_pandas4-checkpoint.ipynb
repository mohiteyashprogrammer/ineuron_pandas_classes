# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.to_csv("Titanic.csv",index=False)

# %%
data = pd.read_csv("Titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.dtypes[data.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data[data.dtypes[data.dtypes == "int64"].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
data[data.dtypes[data.dtypes == "float64"].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data[data["Survived"] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# total dead people in ship
len(data[data["Survived"] == 0])
# Out:
# 549

# %%
# total survived  people in ship
data[data["Survived"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# total survived people in ship
len(data[data["Survived"] == 1])
# Out:
# 342

# %%
# total number of male dead
len(data[(data["Survived"] == 0) & (data["Sex"] == "male")])
# Out:
# 468

# %%
# total number of male survived
len(data[(data["Survived"] == 1) & (data["Sex"] == "male")])
# Out:
# 109

# %%
# total number of female survived
data[(data["Survived"] == 1) & (data["Sex"] == "female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[(data["Survived"] == 1) & (data["Sex"] == "female")])
# Out:
# 233

# %%
# total number of female dead
len(data[(data["Survived"] == 0) & (data["Sex"] == "female")])
# Out:
# 81

# %%
# total number of women in ship
len(data[data["Sex"] == "female"])
# Out:
# 314

# %%
# total number of man in ship
len(data[data["Sex"] == "male"])
# Out:
# 577

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# who are the reach people in ship
data[data["Fare"] == max(data["Fare"])][["Name"]]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
# who are the rich female  in ship
data[(data["Fare"] == max(data["Fare"])) & (data["Sex"] == "female")][["Name","Fare"]]
# Out:
#                  Name      Fare
# 258  Ward, Miss. Anna  512.3292

# %%
# who are the rich male  in ship
data[(data["Fare"] == max(data["Fare"])) & (data["Sex"] == "male")][["Name","Fare"]]
# Out:
#                                    Name      Fare
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 737              Lesurer, Mr. Gustave J  512.3292

# %%
# who are the people lowest paid in ship
data[data["Fare"] == min(data["Fare"])][["Name","Fare"]]
# Out:
#                                  Name  Fare
# 179               Leonard, Mr. Lionel   0.0
# 263             Harrison, Mr. William   0.0
# 271      Tornquist, Mr. William Henry   0.0
# 277       Parkes, Mr. Francis "Frank"   0.0
# 302   Johnson, Mr. William Cahoone Jr   0.0
# 413    Cunningham, Mr. Alfred Fleming   0.0
# 466             Campbell, Mr. William   0.0
# 481  Frost, Mr. Anthony Wood "Archie"   0.0
# 597               Johnson, Mr. Alfred   0.0
# 633     Parr, Mr. William Henry Marsh   0.0
# 674        Watson, Mr. Ennis Hastings   0.0
# 732              Knight, Mr. Robert J   0.0
# 806            Andrews, Mr. Thomas Jr   0.0
# 815                  Fry, Mr. Richard   0.0
# 822   Reuchlin, Jonkheer. John George   0.0

# %%
# who is less pay and survived
data[(data["Fare"] == min(data["Fare"])) & (data["Survived"] == 1)][["Name","Fare"]]
# Out:
#                              Name  Fare
# 271  Tornquist, Mr. William Henry   0.0

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# how many people have there cabin in ship
len(data[data["Cabin"].isnull() == False])
# Out:
# 204

# %%
# how many people have there cabin in ship and who survived
len(data[(data["Cabin"].isnull() == False) & (data["Survived"] == 1)])
# Out:
# 136

# %%
# who are the surviver under age of 20
data[(data["Survived"] == 1) & (data["Age"] < 20)][["Name","Age"]]
# Out:
#                                          Name   Age
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 853                 Lines, Miss. Mary Conover  16.0
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [79 rows x 2 columns]

# %%
# who are the dead under age of 20
data[(data["Survived"] == 0) & (data["Age"] < 20)][["Name","Age"]]
# Out:
#                                         Name   Age
# 7             Palsson, Master. Gosta Leonard   2.0
# 14      Vestrom, Miss. Hulda Amanda Adolfina  14.0
# 16                      Rice, Master. Eugene   2.0
# 24             Palsson, Miss. Torborg Danira   8.0
# 27            Fortune, Mr. Charles Alexander  19.0
# ..                                       ...   ...
# 841                 Mudd, Mr. Thomas Charles  16.0
# 844                      Culumovic, Mr. Jeso  17.0
# 850  Andersson, Master. Sigvard Harald Elias   4.0
# 852                  Boulos, Miss. Nourelain   9.0
# 877                     Petroff, Mr. Nedelio  19.0
#
# [85 rows x 2 columns]

# %%
# who are the  survived age is gater then 50
data[(data["Survived"] == 1) & (data["Age"] >= 50)][["Name","Age"]]
# Out:
#                                                   Name   Age
# 11                            Bonnell, Miss. Elizabeth  58.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0
# 195                               Lurette, Miss. Elise  58.0
# 259                        Parrish, Mrs. (Lutie Davis)  50.0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  58.0
# 275                  Andrews, Miss. Kornelia Theodosia  63.0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.0
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.0
# 449                     Peuchen, Major. Arthur Godfrey  52.0
# 458                                Toomey, Miss. Ellen  50.0
# 483                             Turkula, Mrs. (Hedwig)  63.0
# 496                     Eustis, Miss. Elizabeth Mussey  54.0
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  54.0
# 526                               Ridsdale, Miss. Lucy  50.0
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# person who trevel in first class number
len(data[data["Pclass"] == 1])
# Out:
# 216

# %%
# person who trevel in seconf class number
len(data[data["Pclass"] == 2])
# Out:
# 184

# %%
# person who trevel in third class number
len(data[data["Pclass"] == 3])
# Out:
# 491

# %%
# how meany people are dead in first class
len(data[(data["Survived"] == 0) & (data["Pclass"] == 1)])
# Out:
# 80

# %%
# how meany people are dead in second class
len(data[(data["Survived"] == 0) & (data["Pclass"] == 2)])
# Out:
# 97

# %%
# how meany people are dead in third class
len(data[(data["Survived"] == 0) & (data["Pclass"] == 3)])
# Out:
# 372

# %%
# how many people is greater the 35 in firstclass and survived
len(data[(data["Age"] > 50) & (data["Pclass"]== 1) & data["Survived"] == 1])
# Out:
# 18

# %%
# how many people is less then 20 in firstclass and dead
len(data[(data["Age"] < 20) & (data["Pclass"]==1) & (data["Survived"] == 0)])
# Out:
# 4

# %%
def change(x):
    if x == "S":
        return "A"
    elif x == "C":
        return "B"
    else:
        return "C"

# %%
data["Embarked"] = data["Embarked"].apply(change)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        A
# 1      0          PC 17599  71.2833   C85        B
# 2      0  STON/O2. 3101282   7.9250   NaN        A
# 3      0            113803  53.1000  C123        A
# 4      0            373450   8.0500   NaN        A

# %%
data["Name_agane"] = data["Name"]

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  \
# 0      0  A/5 21171   7.2500   NaN        A
# 1      0   PC 17599  71.2833   C85        B
#
#                                           Name_agane
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
data["add"] = data["Age"] + data["Fare"]

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  \
# 0      0  A/5 21171   7.2500   NaN        A
# 1      0   PC 17599  71.2833   C85        B
#
#                                           Name_agane       add
# 0                            Braund, Mr. Owen Harris   29.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  109.2833

# %%
data.drop("Name_agane",axis=1,inplace=True)

# %%
data.drop(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       B
# add                                                     109.2833
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       B
# add                                                     109.2833
# Name: 1, dtype: object

# %%
data.loc[5:8]
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked       add
# 5      0  330877   8.4583   NaN        C       NaN
# 6      0   17463  51.8625   E46        A  105.8625
# 7      1  349909  21.0750   NaN        A   23.0750
# 8      2  347742  11.1333   NaN        A   38.1333

# %%
data.loc[750:752]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 750          751         1       2                 Wells, Miss. Joan  female
# 751          752         1       3               Moor, Master. Meier    male
# 752          753         0       3  Vande Velde, Mr. Johannes Joseph    male
#
#       Age  SibSp  Parch  Ticket    Fare Cabin Embarked     add
# 750   4.0      1      1   29103  23.000   NaN        A  27.000
# 751   6.0      0      1  392096  12.475  E121        A  18.475
# 752  33.0      0      0  345780   9.500   NaN        A  42.500

# %%
data.loc[500:502,["Sex","Age"]]
# Out:
#         Sex   Age
# 500    male  17.0
# 501  female  21.0
# 502  female   NaN

# %%
data.loc[500:502,["Sex"]] == "male"
# Out:
#        Sex
# 500   True
# 501  False
# 502  False

# %%
data.loc[1:8,["Ticket","Fare"]]
# Out:
#              Ticket     Fare
# 1          PC 17599  71.2833
# 2  STON/O2. 3101282   7.9250
# 3            113803  53.1000
# 4            373450   8.0500
# 5            330877   8.4583
# 6             17463  51.8625
# 7            349909  21.0750
# 8            347742  11.1333

# %%
data.loc[[2,200],["Ticket","Fare"]]
# Out:
#                Ticket   Fare
# 2    STON/O2. 3101282  7.925
# 200            345770  9.500

# %%
data.iloc[2:4,[1,2]]
# Out:
#    Survived  Pclass
# 2         1       3
# 3         1       1

# %%
data.iloc[[1,9],[2,3]]
# Out:
#    Pclass                                               Name
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)

# %%
df = data.loc[1:10,["PassengerId","Survived","Pclass" ,"Sex","Age", "Fare","Cabin"]]

# %%
df
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 2             3         1       3  female  26.0   7.9250   NaN
# 3             4         1       1  female  35.0  53.1000  C123
# 4             5         0       3    male  35.0   8.0500   NaN
# 5             6         0       3    male   NaN   8.4583   NaN
# 6             7         0       1    male  54.0  51.8625   E46
# 7             8         0       3    male   2.0  21.0750   NaN
# 8             9         1       3  female  27.0  11.1333   NaN
# 9            10         1       2  female  14.0  30.0708   NaN
# 10           11         1       3  female   4.0  16.7000    G6

# %%
df.dropna(axis=1)
# Out:
#     PassengerId  Survived  Pclass     Sex     Fare
# 1             2         1       1  female  71.2833
# 2             3         1       3  female   7.9250
# 3             4         1       1  female  53.1000
# 4             5         0       3    male   8.0500
# 5             6         0       3    male   8.4583
# 6             7         0       1    male  51.8625
# 7             8         0       3    male  21.0750
# 8             9         1       3  female  11.1333
# 9            10         1       2  female  30.0708
# 10           11         1       3  female  16.7000

# %%
df.dropna()
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 3             4         1       1  female  35.0  53.1000  C123
# 6             7         0       1    male  54.0  51.8625   E46
# 10           11         1       3  female   4.0  16.7000    G6

# %%
df.fillna("yash")
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 2             3         1       3  female  26.0   7.9250  yash
# 3             4         1       1  female  35.0  53.1000  C123
# 4             5         0       3    male  35.0   8.0500  yash
# 5             6         0       3    male  yash   8.4583  yash
# 6             7         0       1    male  54.0  51.8625   E46
# 7             8         0       3    male   2.0  21.0750  yash
# 8             9         1       3  female  27.0  11.1333  yash
# 9            10         1       2  female  14.0  30.0708  yash
# 10           11         1       3  female   4.0  16.7000    G6

# %%
df.fillna("isha",axis=0,)
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 2             3         1       3  female  26.0   7.9250  isha
# 3             4         1       1  female  35.0  53.1000  C123
# 4             5         0       3    male  35.0   8.0500  isha
# 5             6         0       3    male  isha   8.4583  isha
# 6             7         0       1    male  54.0  51.8625   E46
# 7             8         0       3    male   2.0  21.0750  isha
# 8             9         1       3  female  27.0  11.1333  isha
# 9            10         1       2  female  14.0  30.0708  isha
# 10           11         1       3  female   4.0  16.7000    G6

# %%
data.groupby("Age").mean()
# Out:
#        PassengerId  Survived  Pclass  SibSp  Parch      Fare       add
# Age
# 0.42         804.0       1.0     3.0    0.0    1.0    8.5167    8.9367
# 0.67         756.0       1.0     2.0    1.0    1.0   14.5000   15.1700
# 0.75         557.5       1.0     3.0    2.0    1.0   19.2583   20.0083
# 0.83         455.5       1.0     2.0    0.5    1.5   23.8750   24.7050
# 0.92         306.0       1.0     1.0    1.0    2.0  151.5500  152.4700
# ...            ...       ...     ...    ...    ...       ...       ...
# 70.00        709.5       0.0     1.5    0.5    0.5   40.7500  110.7500
# 70.50        117.0       0.0     3.0    0.0    0.0    7.7500   78.2500
# 71.00        295.5       0.0     1.0    0.0    0.0   42.0792  113.0792
# 74.00        852.0       0.0     3.0    0.0    0.0    7.7750   81.7750
# 80.00        631.0       1.0     1.0    0.0    0.0   30.0000  110.0000
#
# [88 rows x 7 columns]

# %%
df2 = data.loc[9:20,["Pclass" ,"Sex","Age", "Fare","Cabin"]]

# %%
df
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 2             3         1       3  female  26.0   7.9250   NaN
# 3             4         1       1  female  35.0  53.1000  C123
# 4             5         0       3    male  35.0   8.0500   NaN
# 5             6         0       3    male   NaN   8.4583   NaN
# 6             7         0       1    male  54.0  51.8625   E46
# 7             8         0       3    male   2.0  21.0750   NaN
# 8             9         1       3  female  27.0  11.1333   NaN
# 9            10         1       2  female  14.0  30.0708   NaN
# 10           11         1       3  female   4.0  16.7000    G6

# %%
df2
# Out:
#     Pclass     Sex   Age     Fare Cabin
# 9        2  female  14.0  30.0708   NaN
# 10       3  female   4.0  16.7000    G6
# 11       1  female  58.0  26.5500  C103
# 12       3    male  20.0   8.0500   NaN
# 13       3    male  39.0  31.2750   NaN
# 14       3  female  14.0   7.8542   NaN
# 15       2  female  55.0  16.0000   NaN
# 16       3    male   2.0  29.1250   NaN
# 17       2    male   NaN  13.0000   NaN
# 18       3  female  31.0  18.0000   NaN
# 19       3  female   NaN   7.2250   NaN
# 20       2    male  35.0  26.0000   NaN

# %%
pd.concat([df,df2])
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1           2.0       1.0       1  female  38.0  71.2833   C85
# 2           3.0       1.0       3  female  26.0   7.9250   NaN
# 3           4.0       1.0       1  female  35.0  53.1000  C123
# 4           5.0       0.0       3    male  35.0   8.0500   NaN
# 5           6.0       0.0       3    male   NaN   8.4583   NaN
# 6           7.0       0.0       1    male  54.0  51.8625   E46
# 7           8.0       0.0       3    male   2.0  21.0750   NaN
# 8           9.0       1.0       3  female  27.0  11.1333   NaN
# 9          10.0       1.0       2  female  14.0  30.0708   NaN
# 10         11.0       1.0       3  female   4.0  16.7000    G6
# 9           NaN       NaN       2  female  14.0  30.0708   NaN
# 10          NaN       NaN       3  female   4.0  16.7000    G6
# 11          NaN       NaN       1  female  58.0  26.5500  C103
# 12          NaN       NaN       3    male  20.0   8.0500   NaN
# ...

# %%
pd.concat([df,df2],axis=1)
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin  Pclass  \
# 1           2.0       1.0     1.0  female  38.0  71.2833   C85     NaN
# 2           3.0       1.0     3.0  female  26.0   7.9250   NaN     NaN
# 3           4.0       1.0     1.0  female  35.0  53.1000  C123     NaN
# 4           5.0       0.0     3.0    male  35.0   8.0500   NaN     NaN
# 5           6.0       0.0     3.0    male   NaN   8.4583   NaN     NaN
# 6           7.0       0.0     1.0    male  54.0  51.8625   E46     NaN
# 7           8.0       0.0     3.0    male   2.0  21.0750   NaN     NaN
# 8           9.0       1.0     3.0  female  27.0  11.1333   NaN     NaN
# 9          10.0       1.0     2.0  female  14.0  30.0708   NaN     2.0
# 10         11.0       1.0     3.0  female   4.0  16.7000    G6     3.0
# 11          NaN       NaN     NaN     NaN   NaN      NaN   NaN     1.0
# 12          NaN       NaN     NaN     NaN   NaN      NaN   NaN     3.0
# ...

# %%
pd.merge(df,df2)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 0           10         1       2  female  14.0  30.0708   NaN
# 1           11         1       3  female   4.0  16.7000    G6

# %%
pd.merge(df,df2,how="inner",on="Age")
# Out:
#    PassengerId  Survived  Pclass_x   Sex_x   Age   Fare_x Cabin_x  Pclass_y  \
# 0            4         1         1  female  35.0  53.1000    C123         2
# 1            5         0         3    male  35.0   8.0500     NaN         2
# 2            6         0         3    male   NaN   8.4583     NaN         2
# 3            6         0         3    male   NaN   8.4583     NaN         3
# 4            8         0         3    male   2.0  21.0750     NaN         3
# 5           10         1         2  female  14.0  30.0708     NaN         2
# 6           10         1         2  female  14.0  30.0708     NaN         3
# 7           11         1         3  female   4.0  16.7000      G6         3
#
#     Sex_y   Fare_y Cabin_y
# 0    male  26.0000     NaN
# 1    male  26.0000     NaN
# 2    male  13.0000     NaN
# 3  female   7.2250     NaN
# 4    male  29.1250     NaN
# 5  female  30.0708     NaN
# 6  female   7.8542     NaN
# 7  female  16.7000      G6

# %%
pd.merge(df,df2,how="left",on="Sex")
# Out:
#     PassengerId  Survived  Pclass_x     Sex  Age_x   Fare_x Cabin_x  Pclass_y  \
# 0             2         1         1  female   38.0  71.2833     C85         2
# 1             2         1         1  female   38.0  71.2833     C85         3
# 2             2         1         1  female   38.0  71.2833     C85         1
# 3             2         1         1  female   38.0  71.2833     C85         3
# 4             2         1         1  female   38.0  71.2833     C85         2
# ..          ...       ...       ...     ...    ...      ...     ...       ...
# 57           11         1         3  female    4.0  16.7000      G6         1
# 58           11         1         3  female    4.0  16.7000      G6         3
# 59           11         1         3  female    4.0  16.7000      G6         2
# 60           11         1         3  female    4.0  16.7000      G6         3
# 61           11         1         3  female    4.0  16.7000      G6         3
#
#     Age_y   Fare_y Cabin_y
# ...

# %%
pd.merge(df,df2,how="right",on="Sex")
# Out:
#     PassengerId  Survived  Pclass_x     Sex  Age_x   Fare_x Cabin_x  Pclass_y  \
# 0             2         1         1  female   38.0  71.2833     C85         2
# 1             3         1         3  female   26.0   7.9250     NaN         2
# 2             4         1         1  female   35.0  53.1000    C123         2
# 3             9         1         3  female   27.0  11.1333     NaN         2
# 4            10         1         2  female   14.0  30.0708     NaN         2
# ..          ...       ...       ...     ...    ...      ...     ...       ...
# 57           11         1         3  female    4.0  16.7000      G6         3
# 58            5         0         3    male   35.0   8.0500     NaN         2
# 59            6         0         3    male    NaN   8.4583     NaN         2
# 60            7         0         1    male   54.0  51.8625     E46         2
# 61            8         0         3    male    2.0  21.0750     NaN         2
#
#     Age_y   Fare_y Cabin_y
# ...

# %%
pd.merge(df,df2,how="outer",on="Sex")
# Out:
#     PassengerId  Survived  Pclass_x     Sex  Age_x   Fare_x Cabin_x  Pclass_y  \
# 0             2         1         1  female   38.0  71.2833     C85         2
# 1             2         1         1  female   38.0  71.2833     C85         3
# 2             2         1         1  female   38.0  71.2833     C85         1
# 3             2         1         1  female   38.0  71.2833     C85         3
# 4             2         1         1  female   38.0  71.2833     C85         2
# ..          ...       ...       ...     ...    ...      ...     ...       ...
# 57            8         0         3    male    2.0  21.0750     NaN         3
# 58            8         0         3    male    2.0  21.0750     NaN         3
# 59            8         0         3    male    2.0  21.0750     NaN         3
# 60            8         0         3    male    2.0  21.0750     NaN         2
# 61            8         0         3    male    2.0  21.0750     NaN         2
#
#     Age_y   Fare_y Cabin_y
# ...
