# %%
import pandas as pd

# %%
data = pd.read_csv("mail_addresses.csv")

# %%
data.head(2)
# Out:
#    id  location_id                           attention              address_1  \
# 0   1            1  Fair Oaks Intergenerational Center  2600 Middlefield Road
# 1   2            2          PFS Second Career Services       24 Second Avenue
#
#   address_2          city state_province postal_code country
# 0       NaN  Redwood City             CA       94063      US
# 1       NaN     San Mateo             CA       94401      US

# %%
data.tail(2)
# Out:
#     id  location_id    attention                   address_1  address_2  \
# 19  20           20          NaN             123 Main Street        NaN
# 20  21           22  The Foodies  2013 Avenue of the fellows  Suite 100
#
#              city state_province postal_code country
# 19        Fairfax             VA       22031      US
# 20  San Francisco             CA       90210      US

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'attention', 'address_1', 'address_2', 'city',
#        'state_province', 'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'attention',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data[["id","location_id","postal_code"]]
# Out:
#     id  location_id postal_code
# 0    1            1       94063
# 1    2            2       94401
# 2    3            3       94403
# 3    4            4       94401
# 4    5            5       94401
# 5    6            6  94025-9881
# 6    7            7       94025
# 7    8            8  94025-9881
# 8    9            9       94063
# 9   10           10       94063
# 10  11           11       94061
# 11  12           12       94063
# 12  13           13       94065
# 13  14           14       94064
# 14  15           15       94110
# 15  16           16       94088
# 16  17           17       94080
# 17  18           18       94063
# 18  19           19       94403
# 19  20           20       22031
# 20  21           22       90210

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
(data["city"])
# Out:
# 0            Redwood City
# 1               San Mateo
# 2               San Mateo
# 3               San Mateo
# 4               San Mateo
# 5              Menlo Park
# 6              Menlo Park
# 7              Menlo Park
# 8            Redwood City
# 9            Redwood City
# 10           Redwood City
# 11           Redwood City
# 12           Redwood City
# 13           Redwood City
# 14          San Francisco
# 15              Sunnyvale
# 16    South San Francisco
# 17           Redwood City
# 18              San Mateo
# 19                Fairfax
# 20          San Francisco
# Name: city, dtype: object

# %%
len(data)
# Out:
# 21

# %%
data.dtypes
# Out:
# id                 int64
# location_id        int64
# attention         object
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              21 non-null     int64
#  1   location_id     21 non-null     int64
#  2   attention       20 non-null     object
#  3   address_1       21 non-null     object
#  4   address_2       2 non-null      object
#  5   city            21 non-null     object
#  6   state_province  21 non-null     object
#  7   postal_code     21 non-null     object
#  8   country         21 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 1.6+ KB

# %%
data.describe()
# Out:
#               id  location_id
# count  21.000000    21.000000
# mean   11.000000    11.047619
# std     6.204837     6.288690
# min     1.000000     1.000000
# 25%     6.000000     6.000000
# 50%    11.000000    11.000000
# 75%    16.000000    16.000000
# max    21.000000    22.000000

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#              attention         address_1  address_2          city  \
# count               20                21          2            21
# unique              18                16          2             7
# top     Salvation Army  24 Second Avenue  2nd Floor  Redwood City
# freq                 3                 4          1             8
#
#        state_province postal_code country
# count              21          21      21
# unique              2          13       1
# top                CA       94063      US
# freq               20           5      21

# %%
data.head()
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
#
#                address_1 address_2          city state_province postal_code  \
# 0  2600 Middlefield Road       NaN  Redwood City             CA       94063
# 1       24 Second Avenue       NaN     San Mateo             CA       94401
# 2       24 Second Avenue       NaN     San Mateo             CA       94403
# 3       24 Second Avenue       NaN     San Mateo             CA       94401
# 4       24 Second Avenue       NaN     San Mateo             CA       94401
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %%
#fatch data where the cety name is Redwood City
data[data["city"] == "Redwood City"]
# Out:
#     id  location_id                           attention  \
# 0    1            1  Fair Oaks Intergenerational Center
# 8    9            9                    Fair Oaks Branch
# 9   10           10                        Main Library
# 10  11           11                     Schaberg Branch
# 11  12           12                        Project Read
# 12  13           13               Redwood Shores Branch
# 13  14           14                      Salvation Army
# 17  18           18    Redwood City Free Medical Clinic
#
#                 address_1  address_2          city state_province postal_code  \
# 0   2600 Middlefield Road        NaN  Redwood City             CA       94063
# 8   2510 Middlefield Road        NaN  Redwood City             CA       94063
# 9   1044 Middlefield Road        NaN  Redwood City             CA       94063
# 10     2140 Euclid Avenue        NaN  Redwood City             CA       94061
# ...

# %%
# fatch data where city is  Redwood City postal_code is 94063
data[(data["city"] == "Redwood City") & (data["postal_code"] == "94063")]
# Out:
#     id  location_id                           attention  \
# 0    1            1  Fair Oaks Intergenerational Center
# 8    9            9                    Fair Oaks Branch
# 9   10           10                        Main Library
# 11  12           12                        Project Read
# 17  18           18    Redwood City Free Medical Clinic
#
#                 address_1  address_2          city state_province postal_code  \
# 0   2600 Middlefield Road        NaN  Redwood City             CA       94063
# 8   2510 Middlefield Road        NaN  Redwood City             CA       94063
# 9   1044 Middlefield Road        NaN  Redwood City             CA       94063
# 11  1044 Middlefield Road  2nd Floor  Redwood City             CA       94063
# 17       114 Fifth Avenue        NaN  Redwood City             CA       94063
#
#    country
# 0       US
# 8       US
# 9       US
# 11      US
# 17      US

# %%
# count citys
data["city"].value_counts()
# Out:
# Redwood City           8
# San Mateo              5
# Menlo Park             3
# San Francisco          2
# Sunnyvale              1
# South San Francisco    1
# Fairfax                1
# Name: city, dtype: int64

# %%
data[data["id"] == max(data["id"])][["city"]]
# Out:
#              city
# 20  San Francisco

# %%
# fatch data that adress1 is 1044 Middlefield Road 
data[data["address_1"] == "1044 Middlefield Road"]
# Out:
#     id  location_id     attention              address_1  address_2  \
# 9   10           10  Main Library  1044 Middlefield Road        NaN
# 11  12           12  Project Read  1044 Middlefield Road  2nd Floor
#
#             city state_province postal_code country
# 9   Redwood City             CA       94063      US
# 11  Redwood City             CA       94063      US

# %%
data.head()
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
#
#                address_1 address_2          city state_province postal_code  \
# 0  2600 Middlefield Road       NaN  Redwood City             CA       94063
# 1       24 Second Avenue       NaN     San Mateo             CA       94401
# 2       24 Second Avenue       NaN     San Mateo             CA       94403
# 3       24 Second Avenue       NaN     San Mateo             CA       94401
# 4       24 Second Avenue       NaN     San Mateo             CA       94401
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %%
# fatch data address_2 have value
data[data["address_2"].isnull() == False]
# Out:
#     id  location_id     attention                   address_1  address_2  \
# 11  12           12  Project Read       1044 Middlefield Road  2nd Floor
# 20  21           22   The Foodies  2013 Avenue of the fellows  Suite 100
#
#              city state_province postal_code country
# 11   Redwood City             CA       94063      US
# 20  San Francisco             CA       90210      US

# %%
data["new_data"] = 1418 #ading new colum

# %%
data.head()
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
#
#                address_1 address_2          city state_province postal_code  \
# 0  2600 Middlefield Road       NaN  Redwood City             CA       94063
# 1       24 Second Avenue       NaN     San Mateo             CA       94401
# 2       24 Second Avenue       NaN     San Mateo             CA       94403
# 3       24 Second Avenue       NaN     San Mateo             CA       94401
# 4       24 Second Avenue       NaN     San Mateo             CA       94401
#
#   country  new_data
# 0      US      1418
# 1      US      1418
# 2      US      1418
# 3      US      1418
# 4      US      1418

# %%
data["add_colm"] = data["location_id"] + data["id"]

# %%
data.head(2)
# Out:
#    id  location_id                           attention              address_1  \
# 0   1            1  Fair Oaks Intergenerational Center  2600 Middlefield Road
# 1   2            2          PFS Second Career Services       24 Second Avenue
#
#   address_2          city state_province postal_code country  new_data  \
# 0       NaN  Redwood City             CA       94063      US      1418
# 1       NaN     San Mateo             CA       94401      US      1418
#
#    add_colm
# 0         2
# 1         4

# %%
data.drop("add_colm",axis=1,inplace=True)

# %%
data.drop("new_data",axis=1,inplace=True)

# %%
data.head(2)
# Out:
#    id  location_id                           attention              address_1  \
# 0   1            1  Fair Oaks Intergenerational Center  2600 Middlefield Road
# 1   2            2          PFS Second Career Services       24 Second Avenue
#
#   address_2          city state_province postal_code country
# 0       NaN  Redwood City             CA       94063      US
# 1       NaN     San Mateo             CA       94401      US

# %%
data.iloc[0]
# Out:
# id                                                 1
# location_id                                        1
# attention         Fair Oaks Intergenerational Center
# address_1                      2600 Middlefield Road
# address_2                                        NaN
# city                                    Redwood City
# state_province                                    CA
# postal_code                                    94063
# country                                           US
# Name: 0, dtype: object

# %%
data.loc[1]
# Out:
# id                                         2
# location_id                                2
# attention         PFS Second Career Services
# address_1                   24 Second Avenue
# address_2                                NaN
# city                               San Mateo
# state_province                            CA
# postal_code                            94401
# country                                   US
# Name: 1, dtype: object

# %%
data.loc[15:18]
# Out:
#     id  location_id                         attention  \
# 15  16           16                    Salvation Army
# 16  17           17                    Salvation Army
# 17  18           18  Redwood City Free Medical Clinic
# 18  19           19     San Mateo Free Medical/Dental
#
#                   address_1 address_2                 city state_province  \
# 15           P.O. Box 61868       NaN            Sunnyvale             CA
# 16  409 South Spruce Avenue       NaN  South San Francisco             CA
# 17         114 Fifth Avenue       NaN         Redwood City             CA
# 18      19 West 39th Avenue       NaN            San Mateo             CA
#
#    postal_code country
# 15       94088      US
# 16       94080      US
# 17       94063      US
# 18       94403      US

# %%
data.loc[15:17,["city","postal_code"]]
# Out:
#                    city postal_code
# 15            Sunnyvale       94088
# 16  South San Francisco       94080
# 17         Redwood City       94063

# %%
data.iloc[15:17,[1,2]]
# Out:
#     location_id       attention
# 15           16  Salvation Army
# 16           17  Salvation Army

# %%
data.loc[:,["city","postal_code"]]
# Out:
#                    city postal_code
# 0          Redwood City       94063
# 1             San Mateo       94401
# 2             San Mateo       94403
# 3             San Mateo       94401
# 4             San Mateo       94401
# 5            Menlo Park  94025-9881
# 6            Menlo Park       94025
# 7            Menlo Park  94025-9881
# 8          Redwood City       94063
# 9          Redwood City       94063
# 10         Redwood City       94061
# 11         Redwood City       94063
# 12         Redwood City       94065
# 13         Redwood City       94064
# 14        San Francisco       94110
# 15            Sunnyvale       94088
# 16  South San Francisco       94080
# 17         Redwood City       94063
# 18            San Mateo       94403
# 19              Fairfax       22031
# 20        San Francisco       90210

# %%
data.loc[[3,5],["city","postal_code"]]
# Out:
#          city postal_code
# 3   San Mateo       94401
# 5  Menlo Park  94025-9881

# %%
data[(data["id"] > 15) & (data["city"] == "San Francisco")]
# Out:
#     id  location_id    attention                   address_1  address_2  \
# 20  21           22  The Foodies  2013 Avenue of the fellows  Suite 100
#
#              city state_province postal_code country
# 20  San Francisco             CA       90210      US

# %%
data[(data["id"] <= 15) & (data["city"] == "San Francisco")]
# Out:
#     id  location_id                    attention             address_1  \
# 14  15           15  Adult Rehabilitation Center  1500 Valencia Street
#
#    address_2           city state_province postal_code country
# 14       NaN  San Francisco             CA       94110      US

# %%
minidata = data.iloc[0:10,[0,1,2,3,4,5,7]]

# %%
minidata
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
# 5   6            6                         Little House
# 6   7            7                        Rosener House
# 7   8            8       Meals on Wheels - South County
# 8   9            9                     Fair Oaks Branch
# 9  10           10                         Main Library
#
#                address_1 address_2          city postal_code
# 0  2600 Middlefield Road       NaN  Redwood City       94063
# 1       24 Second Avenue       NaN     San Mateo       94401
# 2       24 Second Avenue       NaN     San Mateo       94403
# 3       24 Second Avenue       NaN     San Mateo       94401
# ...

# %%
minidata.dropna(axis=1)
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
# 5   6            6                         Little House
# 6   7            7                        Rosener House
# 7   8            8       Meals on Wheels - South County
# 8   9            9                     Fair Oaks Branch
# 9  10           10                         Main Library
#
#                address_1          city postal_code
# 0  2600 Middlefield Road  Redwood City       94063
# 1       24 Second Avenue     San Mateo       94401
# 2       24 Second Avenue     San Mateo       94403
# 3       24 Second Avenue     San Mateo       94401
# 4       24 Second Avenue     San Mateo       94401
# ...

# %%
minidata.dropna(axis=1,thresh=10)
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
# 5   6            6                         Little House
# 6   7            7                        Rosener House
# 7   8            8       Meals on Wheels - South County
# 8   9            9                     Fair Oaks Branch
# 9  10           10                         Main Library
#
#                address_1          city postal_code
# 0  2600 Middlefield Road  Redwood City       94063
# 1       24 Second Avenue     San Mateo       94401
# 2       24 Second Avenue     San Mateo       94403
# 3       24 Second Avenue     San Mateo       94401
# 4       24 Second Avenue     San Mateo       94401
# ...

# %%
minidata.fillna(786)
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
# 5   6            6                         Little House
# 6   7            7                        Rosener House
# 7   8            8       Meals on Wheels - South County
# 8   9            9                     Fair Oaks Branch
# 9  10           10                         Main Library
#
#                address_1  address_2          city postal_code
# 0  2600 Middlefield Road        786  Redwood City       94063
# 1       24 Second Avenue        786     San Mateo       94401
# 2       24 Second Avenue        786     San Mateo       94403
# 3       24 Second Avenue        786     San Mateo       94401
# ...

# %%
data.groupby("city").count()
# Out:
#                      id  location_id  attention  address_1  address_2  \
# city
# Fairfax               1            1          0          1          0
# Menlo Park            3            3          3          3          0
# Redwood City          8            8          8          8          1
# San Francisco         2            2          2          2          1
# San Mateo             5            5          5          5          0
# South San Francisco   1            1          1          1          0
# Sunnyvale             1            1          1          1          0
#
#                      state_province  postal_code  country
# city
# Fairfax                           1            1        1
# Menlo Park                        3            3        3
# Redwood City                      8            8        8
# San Francisco                     2            2        2
# San Mateo                         5            5        5
# ...

# %%
data.groupby("city").mean()
# Out:
#                        id  location_id
# city
# Fairfax              20.0         20.0
# Menlo Park            7.0          7.0
# Redwood City         11.0         11.0
# San Francisco        18.0         18.5
# San Mateo             6.6          6.6
# South San Francisco  17.0         17.0
# Sunnyvale            16.0         16.0

# %%
# divide id class in to 5 
minidata["new"] = minidata["location_id"].apply(lambda x:x/3)

# %%
minidata
# Out:
#    id  location_id                            attention  \
# 0   1            1   Fair Oaks Intergenerational Center
# 1   2            2           PFS Second Career Services
# 2   3            3           PFS Senior Peer Counseling
# 3   4            4         PFS Family Visitation Center
# 4   5            5  Economic Self - Sufficiency Program
# 5   6            6                         Little House
# 6   7            7                        Rosener House
# 7   8            8       Meals on Wheels - South County
# 8   9            9                     Fair Oaks Branch
# 9  10           10                         Main Library
#
#                address_1 address_2          city postal_code       new
# 0  2600 Middlefield Road       NaN  Redwood City       94063  0.333333
# 1       24 Second Avenue       NaN     San Mateo       94401  0.666667
# 2       24 Second Avenue       NaN     San Mateo       94403  1.000000
# ...

# %%
minidata["attention"] = minidata["attention"].apply(lambda x: "".join(x))

# %%
minidata
# Out:
#    id  location_id                                          attention  \
# 0   1            1  F, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
# 1   2            2  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 2   3            3  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 3   4            4  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 4   5            5  E, ,., , , ,., , , ,., , , ,., ,c, ,., , , ,.,...
# 5   6            6  L, ,., , , ,., , , ,., , , ,., ,i, ,., , , ,.,...
# 6   7            7  R, ,., , , ,., , , ,., , , ,., ,o, ,., , , ,.,...
# 7   8            8  M, ,., , , ,., , , ,., , , ,., ,e, ,., , , ,.,...
# 8   9            9  F, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
# 9  10           10  M, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
#
#                address_1 address_2          city postal_code       new
# 0  2600 Middlefield Road       NaN  Redwood City       94063  0.333333
# ...

# %%
minidata.drop("attention",axis=1)
# Out:
#    id  location_id              address_1 address_2          city postal_code  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City       94063
# 1   2            2       24 Second Avenue       NaN     San Mateo       94401
# 2   3            3       24 Second Avenue       NaN     San Mateo       94403
# 3   4            4       24 Second Avenue       NaN     San Mateo       94401
# 4   5            5       24 Second Avenue       NaN     San Mateo       94401
# 5   6            6      800 Middle Avenue       NaN    Menlo Park  94025-9881
# 6   7            7         500 Arbor Road       NaN    Menlo Park       94025
# 7   8            8      800 Middle Avenue       NaN    Menlo Park  94025-9881
# 8   9            9  2510 Middlefield Road       NaN  Redwood City       94063
# 9  10           10  1044 Middlefield Road       NaN  Redwood City       94063
#
#         new
# 0  0.333333
# 1  0.666667
# 2  1.000000
# 3  1.333333
# 4  1.666667
# 5  2.000000
# 6  2.333333
# ...

# %%
def specif_city(x):
    if x == "San Mateo":
        return x
    else:
        None

# %%
minidata["city"]  = minidata["city"].apply(specif_city)

# %%
minidata
# Out:
#    id  location_id                                          attention  \
# 0   1            1  F, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
# 1   2            2  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 2   3            3  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 3   4            4  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 4   5            5  E, ,., , , ,., , , ,., , , ,., ,c, ,., , , ,.,...
# 5   6            6  L, ,., , , ,., , , ,., , , ,., ,i, ,., , , ,.,...
# 6   7            7  R, ,., , , ,., , , ,., , , ,., ,o, ,., , , ,.,...
# 7   8            8  M, ,., , , ,., , , ,., , , ,., ,e, ,., , , ,.,...
# 8   9            9  F, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
# 9  10           10  M, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
#
#                address_1 address_2  city postal_code       new
# 0  2600 Middlefield Road       NaN  None       94063  0.333333
# 1       24 Second Avenue       NaN  None       94401  0.666667
# ...

# %%
def code(x):
    if x == "94063":
        return "A"
    elif x == "94025-9881":
        return "B"
    else:
        return "C"

# %%
minidata["code_grp"] = minidata["postal_code"].apply(code)

# %%
minidata
# Out:
#    id  location_id                                          attention  \
# 0   1            1  F, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
# 1   2            2  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 2   3            3  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 3   4            4  P, ,., , , ,., , , ,., , , ,., ,F, ,., , , ,.,...
# 4   5            5  E, ,., , , ,., , , ,., , , ,., ,c, ,., , , ,.,...
# 5   6            6  L, ,., , , ,., , , ,., , , ,., ,i, ,., , , ,.,...
# 6   7            7  R, ,., , , ,., , , ,., , , ,., ,o, ,., , , ,.,...
# 7   8            8  M, ,., , , ,., , , ,., , , ,., ,e, ,., , , ,.,...
# 8   9            9  F, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
# 9  10           10  M, ,., , , ,., , , ,., , , ,., ,a, ,., , , ,.,...
#
#                address_1 address_2  city postal_code       new code_grp
# 0  2600 Middlefield Road       NaN  None       94063  0.333333        A
# ...
