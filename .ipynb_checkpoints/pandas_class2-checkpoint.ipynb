# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
data.dtypes# this function give the data type or all colums
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info()# this function give the hole information about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()# this function give statical analysis to data in numerical formet
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# #this is for catagericol colam discription this is one method on small data
data[["Name","Sex","Ticket","Cabin","Embarked"]].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
#check the condition that object is there or not give true or false 
data.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#filter out the object values that is catogericol
data.dtypes[data.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#anadthor short method
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data[data.dtypes[data.dtypes == "int64"].index].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594
# std     257.353842    0.486592    0.836071    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000

# %%
data[data.dtypes[data.dtypes == "float64"].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#fatch data that survived is 0 not dead 
data[data["Survived"] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# this is the number of people that survived
len(data[data["Survived"] == 0])
# Out:
# 549

# %%
#fatch data that survived is 0 notserived  and male
data[(data["Survived"] == 0) & (data["Sex"] == "male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#death of male passanger total number
len(data[(data["Survived"] == 0) & (data["Sex"] == "male")])
# Out:
# 468

# %%
# Survived passanger in male total number is this
len(data[(data["Survived"] == 1) & (data["Sex"] == "male")])
# Out:
# 109

# %%
#death of female passanger total number
len(data[(data["Survived"] == 0) & (data["Sex"] == "female")])
# Out:
# 81

# %%
# Survived passanger in female total number is this
len(data[(data["Survived"] == 1) & (data["Sex"] == "female")])
# Out:
# 233

# %%
#number of male and female on the ship fatch
data["Sex"].value_counts()#this is funcation give value count
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(data[data["Sex"] == "male"])#another method to get valuecount
# Out:
# 577

# %%
len(data[data["Sex"] == "female"])
# Out:
# 314

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#finding the highest fare name in ship
max(data["Fare"])
# Out:
# 512.3292

# %%
#finding the highest fare name in ship
data[data["Fare"] == max(data["Fare"])][["Name"]]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
#finding the highest fare name in ship survived or not
data[data["Fare"] == max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#finding the lowest fare name in ship survived or not
data[data["Fare"] == min(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
#total number of cabin peoplr have in ship 
len(data[data["Cabin"].isnull() == False])#isnull is a function that five you true false valur
# Out:
# 204

# %%
#add new colum
data["new_clm"] = "isha"

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_clm
# 0      0  A/5 21171   7.2500   NaN        S    isha
# 1      0   PC 17599  71.2833   C85        C    isha

# %%
#add duplect name cilum
data["duplicet_name"] = data["Name"]

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_clm  \
# 0      0  A/5 21171   7.2500   NaN        S    isha
# 1      0   PC 17599  71.2833   C85        C    isha
#
#                                        duplicet_name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
#add 2 colum and create new colum
data["age_pclass"] = data["Age"] + data["Pclass"]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_clm  \
# 0      0         A/5 21171   7.2500   NaN        S    isha
# 1      0          PC 17599  71.2833   C85        C    isha
# 2      0  STON/O2. 3101282   7.9250   NaN        S    isha
# 3      0            113803  53.1000  C123        S    isha
# ...

# %%
#this is drop function that drop colum on base of axis
data.drop("age_pclass",axis=1,inplace=True)

# %%
data.head(2) #axis:1 = colum axis:0 = rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_clm  \
# 0      0  A/5 21171   7.2500   NaN        S    isha
# 1      0   PC 17599  71.2833   C85        C    isha
#
#                                        duplicet_name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
#deleting row, row level operation
data.drop(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#fatch first raw in data
data.iloc[1]#this data fatch raw data take inbuild index
# Out:
# PassengerId                                                      2
# Survived                                                         1
# Pclass                                                           1
# Name             Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                         female
# Age                                                           38.0
# SibSp                                                            1
# Parch                                                            0
# Ticket                                                    PC 17599
# Fare                                                       71.2833
# Cabin                                                          C85
# Embarked                                                         C
# new_clm                                                       isha
# duplicet_name    Cumings, Mrs. John Bradley (Florence Briggs Th...
# Name: 1, dtype: object

# %%
data.loc[1]# fatch data and take name index
# Out:
# PassengerId                                                      2
# Survived                                                         1
# Pclass                                                           1
# Name             Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                         female
# Age                                                           38.0
# SibSp                                                            1
# Parch                                                            0
# Ticket                                                    PC 17599
# Fare                                                       71.2833
# Cabin                                                          C85
# Embarked                                                         C
# new_clm                                                       isha
# duplicet_name    Cumings, Mrs. John Bradley (Florence Briggs Th...
# Name: 1, dtype: object

# %%
#fatch data from index 5 to 10
data.loc[5:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket     Fare Cabin Embarked new_clm  \
# 5       0   330877   8.4583   NaN        Q    isha
# 6       0    17463  51.8625   E46        S    isha
# ...

# %%
#fatch data from index 101 to 106 and colum is Survived,Pclass
data.loc[101:106,["Survived","Pclass"]]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
# fatch data 3and4 from dataframe
data.loc[3:4,["Fare","Cabin","Embarked"]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.iloc[2:4,[1,2,3]]#iloc cant give you the row dat like dhis only works with numerical data
# Out:
#    Survived  Pclass                                          Name
# 2         1       3                        Heikkinen, Miss. Laina
# 3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
# fatch colum using loc and i loc
data.loc[:,["Cabin","Embarked"]]
# Out:
#     Cabin Embarked
# 0     NaN        S
# 1     C85        C
# 2     NaN        S
# 3    C123        S
# 4     NaN        S
# ..    ...      ...
# 886   NaN        S
# 887   B42        S
# 888   NaN        S
# 889  C148        C
# 890   NaN        Q
#
# [891 rows x 2 columns]

# %%
# fatch index 3 and 5 from data
data.loc[[3,5],["PassengerId","Survived","Pclass"]]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
# fatch the data age is grater then 35 and pclass is 1
data[(data["Age"] > 35) & (data["Pclass"] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# create mini data set using iloc
datamini = data.iloc[1:11,[0,1,2,4,5,9,10]]

# %%
datamini
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 2             3         1       3  female  26.0   7.9250   NaN
# 3             4         1       1  female  35.0  53.1000  C123
# 4             5         0       3    male  35.0   8.0500   NaN
# 5             6         0       3    male   NaN   8.4583   NaN
# 6             7         0       1    male  54.0  51.8625   E46
# 7             8         0       3    male   2.0  21.0750   NaN
# 8             9         1       3  female  27.0  11.1333   NaN
# 9            10         1       2  female  14.0  30.0708   NaN
# 10           11         1       3  female   4.0  16.7000    G6

# %%
# Rename the data index
datamini.set_index("Sex")#we can set index and re name it
# Out:
#         PassengerId  Survived  Pclass   Age     Fare Cabin
# Sex
# female            2         1       1  38.0  71.2833   C85
# female            3         1       3  26.0   7.9250   NaN
# female            4         1       1  35.0  53.1000  C123
# male              5         0       3  35.0   8.0500   NaN
# male              6         0       3   NaN   8.4583   NaN
# male              7         0       1  54.0  51.8625   E46
# male              8         0       3   2.0  21.0750   NaN
# female            9         1       3  27.0  11.1333   NaN
# female           10         1       2  14.0  30.0708   NaN
# female           11         1       3   4.0  16.7000    G6

# %%
datamini
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 2             3         1       3  female  26.0   7.9250   NaN
# 3             4         1       1  female  35.0  53.1000  C123
# 4             5         0       3    male  35.0   8.0500   NaN
# 5             6         0       3    male   NaN   8.4583   NaN
# 6             7         0       1    male  54.0  51.8625   E46
# 7             8         0       3    male   2.0  21.0750   NaN
# 8             9         1       3  female  27.0  11.1333   NaN
# 9            10         1       2  female  14.0  30.0708   NaN
# 10           11         1       3  female   4.0  16.7000    G6

# %%
datamini.dropna()#this function that drop null values in data
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 3             4         1       1  female  35.0  53.1000  C123
# 6             7         0       1    male  54.0  51.8625   E46
# 10           11         1       3  female   4.0  16.7000    G6

# %%
datamini.dropna(axis=1)#drop nan value from colum
# Out:
#     PassengerId  Survived  Pclass     Sex     Fare
# 1             2         1       1  female  71.2833
# 2             3         1       3  female   7.9250
# 3             4         1       1  female  53.1000
# 4             5         0       3    male   8.0500
# 5             6         0       3    male   8.4583
# 6             7         0       1    male  51.8625
# 7             8         0       3    male  21.0750
# 8             9         1       3  female  11.1333
# 9            10         1       2  female  30.0708
# 10           11         1       3  female  16.7000

# %%
#thresh = Require that many non-NA values. Cannot be combined with how.
datamini.dropna(axis=1,thresh=9)
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare
# 1             2         1       1  female  38.0  71.2833
# 2             3         1       3  female  26.0   7.9250
# 3             4         1       1  female  35.0  53.1000
# 4             5         0       3    male  35.0   8.0500
# 5             6         0       3    male   NaN   8.4583
# 6             7         0       1    male  54.0  51.8625
# 7             8         0       3    male   2.0  21.0750
# 8             9         1       3  female  27.0  11.1333
# 9            10         1       2  female  14.0  30.0708
# 10           11         1       3  female   4.0  16.7000

# %%
# replace empty nan value with actual value
datamini.fillna(1418)
# Out:
#     PassengerId  Survived  Pclass     Sex     Age     Fare Cabin
# 1             2         1       1  female    38.0  71.2833   C85
# 2             3         1       3  female    26.0   7.9250  1418
# 3             4         1       1  female    35.0  53.1000  C123
# 4             5         0       3    male    35.0   8.0500  1418
# 5             6         0       3    male  1418.0   8.4583  1418
# 6             7         0       1    male    54.0  51.8625   E46
# 7             8         0       3    male     2.0  21.0750  1418
# 8             9         1       3  female    27.0  11.1333  1418
# 9            10         1       2  female    14.0  30.0708  1418
# 10           11         1       3  female     4.0  16.7000    G6

# %%
datamini.groupby("Sex").count()#fatch it with group
# Out:
#         PassengerId  Survived  Pclass  Age  Fare  Cabin
# Sex
# female            6         6       6    6     6      3
# male              4         4       4    3     4      1

# %%
datamini.groupby("Sex").mean()#avarage group servived
# Out:
#         PassengerId  Survived    Pclass        Age       Fare
# Sex
# female          6.5       1.0  2.166667  24.000000  31.702067
# male            6.5       0.0  2.500000  30.333333  22.361450

# %%
datamini.groupby("Sex").sum()
# Out:
#         PassengerId  Survived  Pclass    Age      Fare
# Sex
# female           39         6      13  144.0  190.2124
# male             26         0      10   91.0   89.4458

# %%
mini = datamini.iloc[0:4, 0:4]

# %%
mini
# Out:
#    PassengerId  Survived  Pclass     Sex
# 1            2         1       1  female
# 2            3         1       3  female
# 3            4         1       1  female
# 4            5         0       3    male

# %%
#data concanation
newdata = pd.concat([data,datamini,mini],axis=0)#rowwise

# %%
newdata
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 10           11         1       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0    1.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                              Heikkinen, Miss. Laina  female  26.0    0.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                            Allen, Mr. William Henry    male  35.0    0.0
# ..                                                ...     ...   ...    ...
# ...

# %%
#data concanation
newdata = pd.concat([data,datamini,mini],axis=1)#vartical columvise

# %%
newdata
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
datamini
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin
# 1             2         1       1  female  38.0  71.2833   C85
# 2             3         1       3  female  26.0   7.9250   NaN
# 3             4         1       1  female  35.0  53.1000  C123
# 4             5         0       3    male  35.0   8.0500   NaN
# 5             6         0       3    male   NaN   8.4583   NaN
# 6             7         0       1    male  54.0  51.8625   E46
# 7             8         0       3    male   2.0  21.0750   NaN
# 8             9         1       3  female  27.0  11.1333   NaN
# 9            10         1       2  female  14.0  30.0708   NaN
# 10           11         1       3  female   4.0  16.7000    G6

# %%
# divide pclass in to 3 using apply function
datamini["new"] = datamini["Pclass"].apply(lambda x:x/3)

# %%
datamini
# Out:
#     PassengerId  Survived  Pclass     Sex   Age     Fare Cabin       new
# 1             2         1       1  female  38.0  71.2833   C85  0.333333
# 2             3         1       3  female  26.0   7.9250   NaN  1.000000
# 3             4         1       1  female  35.0  53.1000  C123  0.333333
# 4             5         0       3    male  35.0   8.0500   NaN  1.000000
# 5             6         0       3    male   NaN   8.4583   NaN  1.000000
# 6             7         0       1    male  54.0  51.8625   E46  0.333333
# 7             8         0       3    male   2.0  21.0750   NaN  1.000000
# 8             9         1       3  female  27.0  11.1333   NaN  1.000000
# 9            10         1       2  female  14.0  30.0708   NaN  0.666667
# 10           11         1       3  female   4.0  16.7000    G6  1.000000

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_clm  \
# 0      0  A/5 21171   7.2500   NaN        S    isha
# 1      0   PC 17599  71.2833   C85        C    isha
#
#                                        duplicet_name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
#we can find len of name usinf appli anf len function
data["length_name"] = data["Name"].apply(len)

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_clm  \
# 0      0  A/5 21171   7.2500   NaN        S    isha
# 1      0   PC 17599  71.2833   C85        C    isha
#
#                                        duplicet_name  length_name
# 0                            Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           51

# %%
# create log 10
import math
def cust1(x):
    if x < 3:
        return x
    else:
        return math.log10(x)

# %%
mini["pid_filter"] = mini["PassengerId"].apply(cust1)

# %%
mini
# Out:
#    PassengerId  Survived  Pclass     Sex  pid_filter
# 1            2         1       1  female    2.000000
# 2            3         1       3  female    0.477121
# 3            4         1       1  female    0.602060
# 4            5         0       3    male    0.698970

# %%
# give female:1 and male:0 value
def fm(x):
    if x == "female":
        return 1
    else:
        return 0

# %%
mini["Sex"] = mini["Sex"].apply(fm)

# %%
mini
# Out:
#    PassengerId  Survived  Pclass  Sex  pid_filter
# 1            2         1       1    1    2.000000
# 2            3         1       3    1    0.477121
# 3            4         1       1    1    0.602060
# 4            5         0       3    0    0.698970

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# divide category by Fare
def cato(x):
    if x <= 100:
        return "A"
    elif x > 100 and x < 200:
        return "B"
    else:
        return"C"

# %%
data["Fare_grp"] = data["Fare"].apply(cato)# divide catogary A B C

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data["Fare_grp"] == "A"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: Fare_grp, Length: 891, dtype: bool
