# %%
import pandas as pd

# %%
data = pd.read_csv("loan_sanction_test.csv")

# %%
data
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
list(data.columns)
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area']

# %%
data = data[['Loan_ID','Gender','Married','Education','Self_Employed','LoanAmount','Loan_Amount_Term','Property_Area']]

# %%
data
# Out:
#       Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0    LP001015   Male     Yes      Graduate            No       110.0
# 1    LP001022   Male     Yes      Graduate            No       126.0
# 2    LP001031   Male     Yes      Graduate            No       208.0
# 3    LP001035   Male     Yes      Graduate            No       100.0
# 4    LP001051   Male      No  Not Graduate            No        78.0
# ..        ...    ...     ...           ...           ...         ...
# 362  LP002971   Male     Yes  Not Graduate           Yes       113.0
# 363  LP002975   Male     Yes      Graduate            No       115.0
# 364  LP002980   Male      No      Graduate            No       126.0
# 365  LP002986   Male     Yes      Graduate            No       158.0
# 366  LP002989   Male      No      Graduate           Yes        98.0
#
#      Loan_Amount_Term Property_Area
# 0               360.0         Urban
# 1               360.0         Urban
# ...

# %%
data.head()
# Out:
#     Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0  LP001015   Male     Yes      Graduate            No       110.0
# 1  LP001022   Male     Yes      Graduate            No       126.0
# 2  LP001031   Male     Yes      Graduate            No       208.0
# 3  LP001035   Male     Yes      Graduate            No       100.0
# 4  LP001051   Male      No  Not Graduate            No        78.0
#
#    Loan_Amount_Term Property_Area
# 0             360.0         Urban
# 1             360.0         Urban
# 2             360.0         Urban
# 3             360.0         Urban
# 4             360.0         Urban

# %%
data.tail()
# Out:
#       Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 362  LP002971   Male     Yes  Not Graduate           Yes       113.0
# 363  LP002975   Male     Yes      Graduate            No       115.0
# 364  LP002980   Male      No      Graduate            No       126.0
# 365  LP002986   Male     Yes      Graduate            No       158.0
# 366  LP002989   Male      No      Graduate           Yes        98.0
#
#      Loan_Amount_Term Property_Area
# 362             360.0         Urban
# 363             360.0         Urban
# 364             360.0     Semiurban
# 365             360.0         Rural
# 366             180.0         Rural

# %%
data.dtypes
# Out:
# Loan_ID              object
# Gender               object
# Married              object
# Education            object
# Self_Employed        object
# LoanAmount          float64
# Loan_Amount_Term    float64
# Property_Area        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Loan_ID           367 non-null    object
#  1   Gender            356 non-null    object
#  2   Married           367 non-null    object
#  3   Education         367 non-null    object
#  4   Self_Employed     344 non-null    object
#  5   LoanAmount        362 non-null    float64
#  6   Loan_Amount_Term  361 non-null    float64
#  7   Property_Area     367 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 23.1+ KB

# %%
data.describe()
# Out:
#        LoanAmount  Loan_Amount_Term
# count  362.000000        361.000000
# mean   136.132597        342.537396
# std     61.366652         65.156643
# min     28.000000          6.000000
# 25%    100.250000        360.000000
# 50%    125.000000        360.000000
# 75%    158.000000        360.000000
# max    550.000000        480.000000

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#          Loan_ID Gender Married Education Self_Employed Property_Area
# count        367    356     367       367           344           367
# unique       367      2       2         2             2             3
# top     LP001015   Male     Yes  Graduate            No         Urban
# freq           1    286     233       283           307           140

# %%
data.head()
# Out:
#     Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0  LP001015   Male     Yes      Graduate            No       110.0
# 1  LP001022   Male     Yes      Graduate            No       126.0
# 2  LP001031   Male     Yes      Graduate            No       208.0
# 3  LP001035   Male     Yes      Graduate            No       100.0
# 4  LP001051   Male      No  Not Graduate            No        78.0
#
#    Loan_Amount_Term Property_Area
# 0             360.0         Urban
# 1             360.0         Urban
# 2             360.0         Urban
# 3             360.0         Urban
# 4             360.0         Urban

# %%
# fatch data where is male
len(data[data["Gender"] == "Male"])
# Out:
# 286

# %%
# fatch all women in data seat
len(data[data["Gender"] == "Female"])
# Out:
# 70

# %%
#fatch women that are married
len(data[(data["Gender"] == "Female") & (data["Married"] == "Yes")])
# Out:
# 26

# %%
#fatch men that are married
len(data[(data["Gender"] == "Male") & (data["Married"] == "Yes")])
# Out:
# 204

# %%
#fatch women that are not married
len(data[(data["Gender"] == "Female") & (data["Married"] == "No")])
# Out:
# 44

# %%
#fatch men that are not married
len(data[(data["Gender"] == "Male") & (data["Married"] == "No")])
# Out:
# 82

# %%
# fatch data that are married and Graduate
len(data[(data["Married"] == "Yes") & (data["Education"] == "Graduate")])
# Out:
# 176

# %%
# fatch data that are married and not Graduate
len(data[(data["Married"] == "No") & (data["Education"] == "Graduate")])
# Out:
# 107

# %%
# fatch data that women are married and graduate
len(data[(data["Gender"] == "Female") & (data["Married"] == "Yes") & (data["Education"] == "Graduate")])
# Out:
# 21

# %%
# fatch data that men are married and graduate
len(data[(data["Gender"] == "Male") & (data["Married"] == "Yes") & (data["Education"] == "Graduate")])
# Out:
# 154

# %%
# fatch data that women are married and not graduate
data[(data["Gender"] == "Female") & (data["Married"] == "Yes") & (data["Education"] == "Not Graduate")]
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  LoanAmount  \
# 266  LP002442  Female     Yes  Not Graduate            No       112.0
# 270  LP002476  Female     Yes  Not Graduate            No        99.0
# 298  LP002635  Female     Yes  Not Graduate            No       117.0
# 321  LP002786  Female     Yes  Not Graduate            No       181.0
# 332  LP002826  Female     Yes  Not Graduate            No       171.0
#
#      Loan_Amount_Term Property_Area
# 266             480.0         Urban
# 270             360.0         Urban
# 298             360.0     Semiurban
# 321             360.0         Urban
# 332             360.0         Urban

# %%
# how many are from urban 
len(data[(data["Property_Area"] == "Urban")])
# Out:
# 140

# %%
# how many are from semiurban 
len(data[(data["Property_Area"] == "Semiurban")])
# Out:
# 116

# %%
# how many are from Rural
len(data[(data["Property_Area"] == "Rural")])
# Out:
# 111

# %%
# women that are graduate in rural area
len(data[(data["Gender"] == "Female") & (data["Property_Area"] == "Rural") & (data["Education"] == "Graduate")])
# Out:
# 16

# %%
# men that are graduate in rural area
len(data[(data["Gender"] == "Male") & (data["Property_Area"] == "Rural") & (data["Education"] == "Graduate")])
# Out:
# 69

# %%
# men that are graduate in Urban area
len(data[(data["Gender"] == "Male") & (data["Property_Area"] == "Urban") & (data["Education"] == "Graduate")])
# Out:
# 90

# %%
# female that are graduate in Urban area
len(data[(data["Gender"] == "Female") & (data["Property_Area"] == "Urban") & (data["Education"] == "Graduate")])
# Out:
# 18

# %%
data.head()
# Out:
#     Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0  LP001015   Male     Yes      Graduate            No       110.0
# 1  LP001022   Male     Yes      Graduate            No       126.0
# 2  LP001031   Male     Yes      Graduate            No       208.0
# 3  LP001035   Male     Yes      Graduate            No       100.0
# 4  LP001051   Male      No  Not Graduate            No        78.0
#
#    Loan_Amount_Term Property_Area
# 0             360.0         Urban
# 1             360.0         Urban
# 2             360.0         Urban
# 3             360.0         Urban
# 4             360.0         Urban

# %%
data[data["LoanAmount"] == max(data["LoanAmount"])]
# Out:
#       Loan_ID Gender Married Education Self_Employed  LoanAmount  \
# 143  LP001791   Male     Yes  Graduate           Yes       550.0
#
#      Loan_Amount_Term Property_Area
# 143             360.0     Semiurban

# %%
data[data["Loan_Amount_Term"] == max(data["Loan_Amount_Term"])]
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  LoanAmount  \
# 82   LP001445    Male     Yes  Not Graduate            No       149.0
# 101  LP001542  Female     Yes      Graduate            No         NaN
# 200  LP002105    Male     Yes      Graduate           Yes       108.0
# 222  LP002245    Male     Yes  Not Graduate            No        80.0
# 239  LP002329    Male      No      Graduate            No        66.0
# 250  LP002383    Male     Yes      Graduate            No       142.0
# 266  LP002442  Female     Yes  Not Graduate            No       112.0
# 295  LP002612  Female     Yes      Graduate            No        84.0
#
#      Loan_Amount_Term Property_Area
# 82              480.0         Rural
# 101             480.0     Semiurban
# 200             480.0         Rural
# 222             480.0         Urban
# 239             480.0         Urban
# 250             480.0         Urban
# 266             480.0         Urban
# 295             480.0     Semiurban

# %%
data["new"] = data["LoanAmount"] + data["Loan_Amount_Term"]
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_23512\2344808580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["new"] = data["LoanAmount"] + data["Loan_Amount_Term"]

# %%
data
# Out:
#       Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0    LP001015   Male     Yes      Graduate            No       110.0
# 1    LP001022   Male     Yes      Graduate            No       126.0
# 2    LP001031   Male     Yes      Graduate            No       208.0
# 3    LP001035   Male     Yes      Graduate            No       100.0
# 4    LP001051   Male      No  Not Graduate            No        78.0
# ..        ...    ...     ...           ...           ...         ...
# 362  LP002971   Male     Yes  Not Graduate           Yes       113.0
# 363  LP002975   Male     Yes      Graduate            No       115.0
# 364  LP002980   Male      No      Graduate            No       126.0
# 365  LP002986   Male     Yes      Graduate            No       158.0
# 366  LP002989   Male      No      Graduate           Yes        98.0
#
#      Loan_Amount_Term Property_Area    new
# 0               360.0         Urban  470.0
# 1               360.0         Urban  486.0
# ...

# %%
data["new2"] = "yash"
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_23512\3877492268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["new2"] = "yash"

# %%
data
# Out:
#       Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0    LP001015   Male     Yes      Graduate            No       110.0
# 1    LP001022   Male     Yes      Graduate            No       126.0
# 2    LP001031   Male     Yes      Graduate            No       208.0
# 3    LP001035   Male     Yes      Graduate            No       100.0
# 4    LP001051   Male      No  Not Graduate            No        78.0
# ..        ...    ...     ...           ...           ...         ...
# 362  LP002971   Male     Yes  Not Graduate           Yes       113.0
# 363  LP002975   Male     Yes      Graduate            No       115.0
# 364  LP002980   Male      No      Graduate            No       126.0
# 365  LP002986   Male     Yes      Graduate            No       158.0
# 366  LP002989   Male      No      Graduate           Yes        98.0
#
#      Loan_Amount_Term Property_Area    new  new2
# 0               360.0         Urban  470.0  yash
# ...

# %%
data.drop("new2",axis=1,inplace=True)
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_23512\1971919498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop("new2",axis=1,inplace=True)

# %%
data.drop("new",axis=1,inplace=True)
# Out:
# C:\Users\yash mohite\AppData\Local\Temp\ipykernel_23512\617661256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop("new",axis=1,inplace=True)

# %%
data
# Out:
#       Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0    LP001015   Male     Yes      Graduate            No       110.0
# 1    LP001022   Male     Yes      Graduate            No       126.0
# 2    LP001031   Male     Yes      Graduate            No       208.0
# 3    LP001035   Male     Yes      Graduate            No       100.0
# 4    LP001051   Male      No  Not Graduate            No        78.0
# ..        ...    ...     ...           ...           ...         ...
# 362  LP002971   Male     Yes  Not Graduate           Yes       113.0
# 363  LP002975   Male     Yes      Graduate            No       115.0
# 364  LP002980   Male      No      Graduate            No       126.0
# 365  LP002986   Male     Yes      Graduate            No       158.0
# 366  LP002989   Male      No      Graduate           Yes        98.0
#
#      Loan_Amount_Term Property_Area
# 0               360.0         Urban
# 1               360.0         Urban
# ...

# %%
data.drop(4)
# Out:
#       Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0    LP001015   Male     Yes      Graduate            No       110.0
# 1    LP001022   Male     Yes      Graduate            No       126.0
# 2    LP001031   Male     Yes      Graduate            No       208.0
# 3    LP001035   Male     Yes      Graduate            No       100.0
# 5    LP001054   Male     Yes  Not Graduate           Yes       152.0
# ..        ...    ...     ...           ...           ...         ...
# 362  LP002971   Male     Yes  Not Graduate           Yes       113.0
# 363  LP002975   Male     Yes      Graduate            No       115.0
# 364  LP002980   Male      No      Graduate            No       126.0
# 365  LP002986   Male     Yes      Graduate            No       158.0
# 366  LP002989   Male      No      Graduate           Yes        98.0
#
#      Loan_Amount_Term Property_Area
# 0               360.0         Urban
# 1               360.0         Urban
# ...

# %%
data.iloc[1]
# Out:
# Loan_ID             LP001022
# Gender                  Male
# Married                  Yes
# Education           Graduate
# Self_Employed             No
# LoanAmount             126.0
# Loan_Amount_Term       360.0
# Property_Area          Urban
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# Loan_ID             LP001022
# Gender                  Male
# Married                  Yes
# Education           Graduate
# Self_Employed             No
# LoanAmount             126.0
# Loan_Amount_Term       360.0
# Property_Area          Urban
# Name: 1, dtype: object

# %%
data.loc[2:5]
# Out:
#     Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 2  LP001031   Male     Yes      Graduate            No       208.0
# 3  LP001035   Male     Yes      Graduate            No       100.0
# 4  LP001051   Male      No  Not Graduate            No        78.0
# 5  LP001054   Male     Yes  Not Graduate           Yes       152.0
#
#    Loan_Amount_Term Property_Area
# 2             360.0         Urban
# 3             360.0         Urban
# 4             360.0         Urban
# 5             360.0         Urban

# %%
data.loc[300:303]
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  LoanAmount  \
# 300  LP002644    Male     Yes      Graduate           Yes        75.0
# 301  LP002651    Male     Yes      Graduate           NaN       125.0
# 302  LP002654  Female      No      Graduate           Yes       177.0
# 303  LP002657     NaN     Yes  Not Graduate           Yes        68.0
#
#      Loan_Amount_Term Property_Area
# 300             360.0         Urban
# 301             360.0         Urban
# 302             360.0         Rural
# 303             360.0         Rural

# %%
data.loc[300:303,("Loan_ID","LoanAmount")]
# Out:
#       Loan_ID  LoanAmount
# 300  LP002644        75.0
# 301  LP002651       125.0
# 302  LP002654       177.0
# 303  LP002657        68.0

# %%
data.loc[[3,310],["Loan_ID","LoanAmount"]]
# Out:
#       Loan_ID  LoanAmount
# 3    LP001035       100.0
# 310  LP002746       147.0

# %%
data.iloc[1:4,[1,2]]
# Out:
#   Gender Married
# 1   Male     Yes
# 2   Male     Yes
# 3   Male     Yes

# %%
data
# Out:
#       Loan_ID Gender Married     Education Self_Employed  LoanAmount  \
# 0    LP001015   Male     Yes      Graduate            No       110.0
# 1    LP001022   Male     Yes      Graduate            No       126.0
# 2    LP001031   Male     Yes      Graduate            No       208.0
# 3    LP001035   Male     Yes      Graduate            No       100.0
# 4    LP001051   Male      No  Not Graduate            No        78.0
# ..        ...    ...     ...           ...           ...         ...
# 362  LP002971   Male     Yes  Not Graduate           Yes       113.0
# 363  LP002975   Male     Yes      Graduate            No       115.0
# 364  LP002980   Male      No      Graduate            No       126.0
# 365  LP002986   Male     Yes      Graduate            No       158.0
# 366  LP002989   Male      No      Graduate           Yes        98.0
#
#      Loan_Amount_Term Property_Area
# 0               360.0         Urban
# 1               360.0         Urban
# ...

# %%
df = data.loc[1:15,("Loan_ID","Self_Employed","Loan_Amount_Term","Gender","Married")]

# %%
df
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term  Gender Married
# 1   LP001022            No             360.0    Male     Yes
# 2   LP001031            No             360.0    Male     Yes
# 3   LP001035            No             360.0    Male     Yes
# 4   LP001051            No             360.0    Male      No
# 5   LP001054           Yes             360.0    Male     Yes
# 6   LP001055            No             360.0  Female      No
# 7   LP001056            No             360.0    Male     Yes
# 8   LP001059           NaN             240.0    Male     Yes
# 9   LP001067            No             360.0    Male      No
# 10  LP001078            No             360.0    Male      No
# 11  LP001082           NaN             360.0    Male     Yes
# 12  LP001083            No             180.0    Male      No
# 13  LP001094           NaN             360.0    Male     Yes
# 14  LP001096            No             360.0  Female      No
# ...

# %%
df.dropna(axis=0)
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term  Gender Married
# 1   LP001022            No             360.0    Male     Yes
# 2   LP001031            No             360.0    Male     Yes
# 3   LP001035            No             360.0    Male     Yes
# 4   LP001051            No             360.0    Male      No
# 5   LP001054           Yes             360.0    Male     Yes
# 6   LP001055            No             360.0  Female      No
# 7   LP001056            No             360.0    Male     Yes
# 9   LP001067            No             360.0    Male      No
# 10  LP001078            No             360.0    Male      No
# 12  LP001083            No             180.0    Male      No
# 14  LP001096            No             360.0  Female      No
# 15  LP001099            No             360.0    Male      No

# %%
df.dropna(axis=1)
# Out:
#      Loan_ID  Loan_Amount_Term  Gender Married
# 1   LP001022             360.0    Male     Yes
# 2   LP001031             360.0    Male     Yes
# 3   LP001035             360.0    Male     Yes
# 4   LP001051             360.0    Male      No
# 5   LP001054             360.0    Male     Yes
# 6   LP001055             360.0  Female      No
# 7   LP001056             360.0    Male     Yes
# 8   LP001059             240.0    Male     Yes
# 9   LP001067             360.0    Male      No
# 10  LP001078             360.0    Male      No
# 11  LP001082             360.0    Male     Yes
# 12  LP001083             180.0    Male      No
# 13  LP001094             360.0    Male     Yes
# 14  LP001096             360.0  Female      No
# 15  LP001099             360.0    Male      No

# %%
df.fillna("Yes")
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term  Gender Married
# 1   LP001022            No             360.0    Male     Yes
# 2   LP001031            No             360.0    Male     Yes
# 3   LP001035            No             360.0    Male     Yes
# 4   LP001051            No             360.0    Male      No
# 5   LP001054           Yes             360.0    Male     Yes
# 6   LP001055            No             360.0  Female      No
# 7   LP001056            No             360.0    Male     Yes
# 8   LP001059           Yes             240.0    Male     Yes
# 9   LP001067            No             360.0    Male      No
# 10  LP001078            No             360.0    Male      No
# 11  LP001082           Yes             360.0    Male     Yes
# 12  LP001083            No             180.0    Male      No
# 13  LP001094           Yes             360.0    Male     Yes
# 14  LP001096            No             360.0  Female      No
# ...

# %%
df.groupby("Gender").count()
# Out:
#         Loan_ID  Self_Employed  Loan_Amount_Term  Married
# Gender
# Female        2              2                 2        2
# Male         13             10                13       13

# %%
df.groupby("Gender").sum()
# Out:
#         Loan_Amount_Term
# Gender
# Female             720.0
# Male              4380.0

# %%
df["Loan_Amount_Term"] = df["Loan_Amount_Term"].apply(lambda x: x/5)

# %%
df
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term  Gender Married
# 1   LP001022            No              72.0    Male     Yes
# 2   LP001031            No              72.0    Male     Yes
# 3   LP001035            No              72.0    Male     Yes
# 4   LP001051            No              72.0    Male      No
# 5   LP001054           Yes              72.0    Male     Yes
# 6   LP001055            No              72.0  Female      No
# 7   LP001056            No              72.0    Male     Yes
# 8   LP001059           NaN              48.0    Male     Yes
# 9   LP001067            No              72.0    Male      No
# 10  LP001078            No              72.0    Male      No
# 11  LP001082           NaN              72.0    Male     Yes
# 12  LP001083            No              36.0    Male      No
# 13  LP001094           NaN              72.0    Male     Yes
# 14  LP001096            No              72.0  Female      No
# ...

# %%
df1 = df.iloc[10:15,[0,1,2]]

# %%
df1
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term
# 11  LP001082           NaN              72.0
# 12  LP001083            No              36.0
# 13  LP001094           NaN              72.0
# 14  LP001096            No              72.0
# 15  LP001099            No              72.0

# %%
df
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term  Gender Married
# 1   LP001022            No              72.0    Male     Yes
# 2   LP001031            No              72.0    Male     Yes
# 3   LP001035            No              72.0    Male     Yes
# 4   LP001051            No              72.0    Male      No
# 5   LP001054           Yes              72.0    Male     Yes
# 6   LP001055            No              72.0  Female      No
# 7   LP001056            No              72.0    Male     Yes
# 8   LP001059           NaN              48.0    Male     Yes
# 9   LP001067            No              72.0    Male      No
# 10  LP001078            No              72.0    Male      No
# 11  LP001082           NaN              72.0    Male     Yes
# 12  LP001083            No              36.0    Male      No
# 13  LP001094           NaN              72.0    Male     Yes
# 14  LP001096            No              72.0  Female      No
# ...

# %%
pd.concat([df1,df],axis=1)
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term   Loan_ID Self_Employed  \
# 11  LP001082           NaN              72.0  LP001082           NaN
# 12  LP001083            No              36.0  LP001083            No
# 13  LP001094           NaN              72.0  LP001094           NaN
# 14  LP001096            No              72.0  LP001096            No
# 15  LP001099            No              72.0  LP001099            No
# 1        NaN           NaN               NaN  LP001022            No
# 2        NaN           NaN               NaN  LP001031            No
# 3        NaN           NaN               NaN  LP001035            No
# 4        NaN           NaN               NaN  LP001051            No
# 5        NaN           NaN               NaN  LP001054           Yes
# 6        NaN           NaN               NaN  LP001055            No
# 7        NaN           NaN               NaN  LP001056            No
# 8        NaN           NaN               NaN  LP001059           NaN
# ...

# %%
pd.concat([df1,df],axis=0)
# Out:
#      Loan_ID Self_Employed  Loan_Amount_Term  Gender Married
# 11  LP001082           NaN              72.0     NaN     NaN
# 12  LP001083            No              36.0     NaN     NaN
# 13  LP001094           NaN              72.0     NaN     NaN
# 14  LP001096            No              72.0     NaN     NaN
# 15  LP001099            No              72.0     NaN     NaN
# 1   LP001022            No              72.0    Male     Yes
# 2   LP001031            No              72.0    Male     Yes
# 3   LP001035            No              72.0    Male     Yes
# 4   LP001051            No              72.0    Male      No
# 5   LP001054           Yes              72.0    Male     Yes
# 6   LP001055            No              72.0  Female      No
# 7   LP001056            No              72.0    Male     Yes
# 8   LP001059           NaN              48.0    Male     Yes
# 9   LP001067            No              72.0    Male      No
# ...

# %%
pd.merge(df,df1)
# Out:
#     Loan_ID Self_Employed  Loan_Amount_Term  Gender Married
# 0  LP001082           NaN              72.0    Male     Yes
# 1  LP001083            No              36.0    Male      No
# 2  LP001094           NaN              72.0    Male     Yes
# 3  LP001096            No              72.0  Female      No
# 4  LP001099            No              72.0    Male      No

# %%
pd.merge(df,df1,how="inner",on="Loan_ID")
# Out:
#     Loan_ID Self_Employed_x  Loan_Amount_Term_x  Gender Married  \
# 0  LP001082             NaN                72.0    Male     Yes
# 1  LP001083              No                36.0    Male      No
# 2  LP001094             NaN                72.0    Male     Yes
# 3  LP001096              No                72.0  Female      No
# 4  LP001099              No                72.0    Male      No
#
#   Self_Employed_y  Loan_Amount_Term_y
# 0             NaN                72.0
# 1              No                36.0
# 2             NaN                72.0
# 3              No                72.0
# 4              No                72.0

# %%
pd.merge(df,df1,how="outer",on="Loan_ID")
# Out:
#      Loan_ID Self_Employed_x  Loan_Amount_Term_x  Gender Married  \
# 0   LP001022              No                72.0    Male     Yes
# 1   LP001031              No                72.0    Male     Yes
# 2   LP001035              No                72.0    Male     Yes
# 3   LP001051              No                72.0    Male      No
# 4   LP001054             Yes                72.0    Male     Yes
# 5   LP001055              No                72.0  Female      No
# 6   LP001056              No                72.0    Male     Yes
# 7   LP001059             NaN                48.0    Male     Yes
# 8   LP001067              No                72.0    Male      No
# 9   LP001078              No                72.0    Male      No
# 10  LP001082             NaN                72.0    Male     Yes
# 11  LP001083              No                36.0    Male      No
# 12  LP001094             NaN                72.0    Male     Yes
# ...

# %%
pd.merge(df,df1,how="left",on="Loan_ID")
# Out:
#      Loan_ID Self_Employed_x  Loan_Amount_Term_x  Gender Married  \
# 0   LP001022              No                72.0    Male     Yes
# 1   LP001031              No                72.0    Male     Yes
# 2   LP001035              No                72.0    Male     Yes
# 3   LP001051              No                72.0    Male      No
# 4   LP001054             Yes                72.0    Male     Yes
# 5   LP001055              No                72.0  Female      No
# 6   LP001056              No                72.0    Male     Yes
# 7   LP001059             NaN                48.0    Male     Yes
# 8   LP001067              No                72.0    Male      No
# 9   LP001078              No                72.0    Male      No
# 10  LP001082             NaN                72.0    Male     Yes
# 11  LP001083              No                36.0    Male      No
# 12  LP001094             NaN                72.0    Male     Yes
# ...

# %%
pd.merge(df,df1,how="right",on="Loan_ID")
# Out:
#     Loan_ID Self_Employed_x  Loan_Amount_Term_x  Gender Married  \
# 0  LP001082             NaN                72.0    Male     Yes
# 1  LP001083              No                36.0    Male      No
# 2  LP001094             NaN                72.0    Male     Yes
# 3  LP001096              No                72.0  Female      No
# 4  LP001099              No                72.0    Male      No
#
#   Self_Employed_y  Loan_Amount_Term_y
# 0             NaN                72.0
# 1              No                36.0
# 2             NaN                72.0
# 3              No                72.0
# 4              No                72.0
