# %%
import pandas as pd

# %%
data = pd.read_csv("iris.csv",header=None,names=["sepal_length","sepal_width","petal_length","petal_width","flower_type"])

# %%
data.drop(0,inplace=True)

# %%
data.head()
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type
# 1          5.1         3.5          1.4         0.2  Iris-setosa
# 2          4.9         3.0          1.4         0.2  Iris-setosa
# 3          4.7         3.2          1.3         0.2  Iris-setosa
# 4          4.6         3.1          1.5         0.2  Iris-setosa
# 5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
data.tail()
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type
# 146          6.7         3.0          5.2         2.3  Iris-virginica
# 147          6.3         2.5          5.0         1.9  Iris-virginica
# 148          6.5         3.0          5.2         2.0  Iris-virginica
# 149          6.2         3.4          5.4         2.3  Iris-virginica
# 150          5.9         3.0          5.1         1.8  Iris-virginica

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
list(data.columns)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'flower_type']

# %%
data[["flower_type"]]
# Out:
#         flower_type
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
#
# [150 rows x 1 columns]

# %%
data.dtypes
# Out:
# sepal_length    object
# sepal_width     object
# petal_length    object
# petal_width     object
# flower_type     object
# dtype: object

# %%
data.describe()
# Out:
#        sepal_length sepal_width petal_length petal_width  flower_type
# count           150         150          150         150          150
# unique           35          23           43          22            3
# top             5.0         3.0          1.5         0.2  Iris-setosa
# freq             10          26           14          28           50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    object
#  1   sepal_width   150 non-null    object
#  2   petal_length  150 non-null    object
#  3   petal_width   150 non-null    object
#  4   flower_type   150 non-null    object
# dtypes: object(5)
# memory usage: 6.0+ KB

# %%
data.head()
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type
# 1          5.1         3.5          1.4         0.2  Iris-setosa
# 2          4.9         3.0          1.4         0.2  Iris-setosa
# 3          4.7         3.2          1.3         0.2  Iris-setosa
# 4          4.6         3.1          1.5         0.2  Iris-setosa
# 5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
data[(data["flower_type"] == "Iris-setosa") & (data["sepal_width"] == "3.5")]
# Out:
#    sepal_length sepal_width petal_length petal_width  flower_type
# 1           5.1         3.5          1.4         0.2  Iris-setosa
# 18          5.1         3.5          1.4         0.3  Iris-setosa
# 28          5.2         3.5          1.5         0.2  Iris-setosa
# 37          5.5         3.5          1.3         0.2  Iris-setosa
# 41          5.0         3.5          1.3         0.3  Iris-setosa
# 44          5.0         3.5          1.6         0.6  Iris-setosa

# %%
data[(data["flower_type"] == "Iris-versicolor") & (data["sepal_length"] == "7.0")]
# Out:
#    sepal_length sepal_width petal_length petal_width      flower_type
# 51          7.0         3.2          4.7         1.4  Iris-versicolor

# %%
data[(data["petal_length"] == "1.5") & (data["flower_type"] == "Iris-setosa")]
# Out:
#    sepal_length sepal_width petal_length petal_width  flower_type
# 4           4.6         3.1          1.5         0.2  Iris-setosa
# 8           5.0         3.4          1.5         0.2  Iris-setosa
# 10          4.9         3.1          1.5         0.1  Iris-setosa
# 11          5.4         3.7          1.5         0.2  Iris-setosa
# 16          5.7         4.4          1.5         0.4  Iris-setosa
# 20          5.1         3.8          1.5         0.3  Iris-setosa
# 22          5.1         3.7          1.5         0.4  Iris-setosa
# 28          5.2         3.5          1.5         0.2  Iris-setosa
# 32          5.4         3.4          1.5         0.4  Iris-setosa
# 33          5.2         4.1          1.5         0.1  Iris-setosa
# 35          4.9         3.1          1.5         0.1  Iris-setosa
# 38          4.9         3.1          1.5         0.1  Iris-setosa
# 40          5.1         3.4          1.5         0.2  Iris-setosa
# ...

# %%
data[data["flower_type"] == "Iris-virginica"]
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type
# 101          6.3         3.3          6.0         2.5  Iris-virginica
# 102          5.8         2.7          5.1         1.9  Iris-virginica
# 103          7.1         3.0          5.9         2.1  Iris-virginica
# 104          6.3         2.9          5.6         1.8  Iris-virginica
# 105          6.5         3.0          5.8         2.2  Iris-virginica
# 106          7.6         3.0          6.6         2.1  Iris-virginica
# 107          4.9         2.5          4.5         1.7  Iris-virginica
# 108          7.3         2.9          6.3         1.8  Iris-virginica
# 109          6.7         2.5          5.8         1.8  Iris-virginica
# 110          7.2         3.6          6.1         2.5  Iris-virginica
# 111          6.5         3.2          5.1         2.0  Iris-virginica
# 112          6.4         2.7          5.3         1.9  Iris-virginica
# ...

# %%
len(data[data["flower_type"] == "Iris-virginica"])
# Out:
# 50

# %%
data[(data["flower_type"] == "Iris-virginica") &(data["sepal_length"] == "7.7")]
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type
# 118          7.7         3.8          6.7         2.2  Iris-virginica
# 119          7.7         2.6          6.9         2.3  Iris-virginica
# 123          7.7         2.8          6.7         2.0  Iris-virginica
# 136          7.7         3.0          6.1         2.3  Iris-virginica

# %%
data[data["petal_length"] == max(data["petal_length"])]
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type
# 119          7.7         2.6          6.9         2.3  Iris-virginica

# %%
data[data["sepal_length"] == max(data["sepal_length"])]
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type
# 132          7.9         3.8          6.4         2.0  Iris-virginica

# %%
data["new_colm"] = 56

# %%
data.head()
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type  new_colm
# 1          5.1         3.5          1.4         0.2  Iris-setosa        56
# 2          4.9         3.0          1.4         0.2  Iris-setosa        56
# 3          4.7         3.2          1.3         0.2  Iris-setosa        56
# 4          4.6         3.1          1.5         0.2  Iris-setosa        56
# 5          5.0         3.6          1.4         0.2  Iris-setosa        56

# %%
data["sepal_petel"] = data["sepal_length"] + data["petal_length"]

# %%
data.head()
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type  new_colm  \
# 1          5.1         3.5          1.4         0.2  Iris-setosa        56
# 2          4.9         3.0          1.4         0.2  Iris-setosa        56
# 3          4.7         3.2          1.3         0.2  Iris-setosa        56
# 4          4.6         3.1          1.5         0.2  Iris-setosa        56
# 5          5.0         3.6          1.4         0.2  Iris-setosa        56
#
#   sepal_petel
# 1      5.11.4
# 2      4.91.4
# 3      4.71.3
# 4      4.61.5
# 5      5.01.4

# %%
data.drop("new_colm",axis=1,inplace=True)

# %%
data.head(2)
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type sepal_petel
# 1          5.1         3.5          1.4         0.2  Iris-setosa      5.11.4
# 2          4.9         3.0          1.4         0.2  Iris-setosa      4.91.4

# %%
data.iloc[1]
# Out:
# sepal_length            4.9
# sepal_width             3.0
# petal_length            1.4
# petal_width             0.2
# flower_type     Iris-setosa
# sepal_petel          4.91.4
# Name: 2, dtype: object

# %%
data.loc[1]
# Out:
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# flower_type     Iris-setosa
# sepal_petel          5.11.4
# Name: 1, dtype: object

# %%
data.loc[111:117]
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type  \
# 111          6.5         3.2          5.1         2.0  Iris-virginica
# 112          6.4         2.7          5.3         1.9  Iris-virginica
# 113          6.8         3.0          5.5         2.1  Iris-virginica
# 114          5.7         2.5          5.0         2.0  Iris-virginica
# 115          5.8         2.8          5.1         2.4  Iris-virginica
# 116          6.4         3.2          5.3         2.3  Iris-virginica
# 117          6.5         3.0          5.5         1.8  Iris-virginica
#
#     sepal_petel
# 111      6.55.1
# 112      6.45.3
# 113      6.85.5
# 114      5.75.0
# 115      5.85.1
# 116      6.45.3
# 117      6.55.5

# %%
data.loc[1:3]
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type sepal_petel
# 1          5.1         3.5          1.4         0.2  Iris-setosa      5.11.4
# 2          4.9         3.0          1.4         0.2  Iris-setosa      4.91.4
# 3          4.7         3.2          1.3         0.2  Iris-setosa      4.71.3

# %%
data.loc[100:103,["flower_type","sepal_petel"]]
# Out:
#          flower_type sepal_petel
# 100  Iris-versicolor      5.74.1
# 101   Iris-virginica      6.36.0
# 102   Iris-virginica      5.85.1
# 103   Iris-virginica      7.15.9

# %%
data.loc[[1,150]]
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type  \
# 1            5.1         3.5          1.4         0.2     Iris-setosa
# 150          5.9         3.0          5.1         1.8  Iris-virginica
#
#     sepal_petel
# 1        5.11.4
# 150      5.95.1

# %%
data.groupby("flower_type").count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width  \
# flower_type
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50
#
#                  sepal_petel
# flower_type
# Iris-setosa               50
# Iris-versicolor           50
# Iris-virginica            50

# %%
mini = data.iloc[0:5,0:5]

# %%
mini
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type
# 1          5.1         3.5          1.4         0.2  Iris-setosa
# 2          4.9         3.0          1.4         0.2  Iris-setosa
# 3          4.7         3.2          1.3         0.2  Iris-setosa
# 4          4.6         3.1          1.5         0.2  Iris-setosa
# 5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
new = pd.concat([data,mini],axis=0)

# %%
new
# Out:
#    sepal_length sepal_width petal_length petal_width  flower_type sepal_petel
# 1           5.1         3.5          1.4         0.2  Iris-setosa      5.11.4
# 2           4.9         3.0          1.4         0.2  Iris-setosa      4.91.4
# 3           4.7         3.2          1.3         0.2  Iris-setosa      4.71.3
# 4           4.6         3.1          1.5         0.2  Iris-setosa      4.61.5
# 5           5.0         3.6          1.4         0.2  Iris-setosa      5.01.4
# ..          ...         ...          ...         ...          ...         ...
# 1           5.1         3.5          1.4         0.2  Iris-setosa         NaN
# 2           4.9         3.0          1.4         0.2  Iris-setosa         NaN
# 3           4.7         3.2          1.3         0.2  Iris-setosa         NaN
# 4           4.6         3.1          1.5         0.2  Iris-setosa         NaN
# 5           5.0         3.6          1.4         0.2  Iris-setosa         NaN
#
# [155 rows x 6 columns]

# %%
new = pd.concat([data,mini],axis=1)

# %%
new
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type  \
# 1            5.1         3.5          1.4         0.2     Iris-setosa
# 2            4.9         3.0          1.4         0.2     Iris-setosa
# 3            4.7         3.2          1.3         0.2     Iris-setosa
# 4            4.6         3.1          1.5         0.2     Iris-setosa
# 5            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 146          6.7         3.0          5.2         2.3  Iris-virginica
# 147          6.3         2.5          5.0         1.9  Iris-virginica
# 148          6.5         3.0          5.2         2.0  Iris-virginica
# 149          6.2         3.4          5.4         2.3  Iris-virginica
# 150          5.9         3.0          5.1         1.8  Iris-virginica
#
#     sepal_petel sepal_length sepal_width petal_length petal_width  flower_type
# ...

# %%
new.dropna(axis=1)
# Out:
#     sepal_length sepal_width petal_length petal_width     flower_type  \
# 1            5.1         3.5          1.4         0.2     Iris-setosa
# 2            4.9         3.0          1.4         0.2     Iris-setosa
# 3            4.7         3.2          1.3         0.2     Iris-setosa
# 4            4.6         3.1          1.5         0.2     Iris-setosa
# 5            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 146          6.7         3.0          5.2         2.3  Iris-virginica
# 147          6.3         2.5          5.0         1.9  Iris-virginica
# 148          6.5         3.0          5.2         2.0  Iris-virginica
# 149          6.2         3.4          5.4         2.3  Iris-virginica
# 150          5.9         3.0          5.1         1.8  Iris-virginica
#
#     sepal_petel
# 1        5.11.4
# 2        4.91.4
# 3        4.71.3
# 4        4.61.5
# 5        5.01.4
# ..          ...
# ...

# %%
data.head()
# Out:
#   sepal_length sepal_width petal_length petal_width  flower_type sepal_petel
# 1          5.1         3.5          1.4         0.2  Iris-setosa      5.11.4
# 2          4.9         3.0          1.4         0.2  Iris-setosa      4.91.4
# 3          4.7         3.2          1.3         0.2  Iris-setosa      4.71.3
# 4          4.6         3.1          1.5         0.2  Iris-setosa      4.61.5
# 5          5.0         3.6          1.4         0.2  Iris-setosa      5.01.4

# %%
data["flower_type"] = data["flower_type"].apply(lambda x:x.replace(" ",""))

# %%
data
# Out:
#     sepal_length sepal_width petal_length petal_width    flower_type  \
# 1            5.1         3.5          1.4         0.2     Irissetosa
# 2            4.9         3.0          1.4         0.2     Irissetosa
# 3            4.7         3.2          1.3         0.2     Irissetosa
# 4            4.6         3.1          1.5         0.2     Irissetosa
# 5            5.0         3.6          1.4         0.2     Irissetosa
# ..           ...         ...          ...         ...            ...
# 146          6.7         3.0          5.2         2.3  Irisvirginica
# 147          6.3         2.5          5.0         1.9  Irisvirginica
# 148          6.5         3.0          5.2         2.0  Irisvirginica
# 149          6.2         3.4          5.4         2.3  Irisvirginica
# 150          5.9         3.0          5.1         1.8  Irisvirginica
#
#     sepal_petel
# 1        5.11.4
# 2        4.91.4
# 3        4.71.3
# 4        4.61.5
# 5        5.01.4
# ..          ...
# ...

# %%
def test(x):
    if x == None:
        return "good"

# %%
data["sepal_length"] = data["sepal_length"].apply(test)

# %%
data
# Out:
#     sepal_length sepal_width petal_length petal_width    flower_type  \
# 1           good         3.5          1.4         0.2     Irissetosa
# 2           good         3.0          1.4         0.2     Irissetosa
# 3           good         3.2          1.3         0.2     Irissetosa
# 4           good         3.1          1.5         0.2     Irissetosa
# 5           good         3.6          1.4         0.2     Irissetosa
# ..           ...         ...          ...         ...            ...
# 146         good         3.0          5.2         2.3  Irisvirginica
# 147         good         2.5          5.0         1.9  Irisvirginica
# 148         good         3.0          5.2         2.0  Irisvirginica
# 149         good         3.4          5.4         2.3  Irisvirginica
# 150         good         3.0          5.1         1.8  Irisvirginica
#
#     sepal_petel
# 1        5.11.4
# 2        4.91.4
# 3        4.71.3
# 4        4.61.5
# 5        5.01.4
# ..          ...
# ...
