# %%
import pandas as pd

# %%
data = pd.read_csv("addresses.csv")# pandas always work in structure data

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data) #dataframe is the type of data in pandas
# Out:
# pandas.core.frame.DataFrame

# %%
data.head() #this id the function of pandas to show first five line in data
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data.tail()#this id the function of pandas to show last five line in data
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.columns #in panda we can also extract colums  by this instance
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)#this data is  object we convert it in to list
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data[['id','city','address_1']]# fatching specific colum always pass them in list to fatch
# Out:
#     id                 city                   address_1
# 0    1         Redwood City       2600 Middlefield Road
# 1    2            San Mateo            24 Second Avenue
# 2    3            San Mateo            24 Second Avenue
# 3    4            San Mateo            24 Second Avenue
# 4    5            San Mateo            24 Second Avenue
# 5    6           Menlo Park           800 Middle Avenue
# 6    7           Menlo Park              500 Arbor Road
# 7    8           Menlo Park           800 Middle Avenue
# 8    9         Redwood City       2510 Middlefield Road
# 9   10         Redwood City       1044 Middlefield Road
# 10  11         Redwood City         2140 Euclid Avenue.
# 11  12         Redwood City       1044 Middlefield Road
# 12  13         Redwood City         399 Marine Parkway.
# 13  14         Redwood City          660 Veterans Blvd.
# 14  15        San Francisco        1500 Valencia Street
# 15  16            Sunnyvale         1161 South Bernardo
# ...

# %%
data["city"]# if we pass data in normal coats the type will be series  not dataframe
# Out:
# 0            Redwood City
# 1               San Mateo
# 2               San Mateo
# 3               San Mateo
# 4               San Mateo
# 5              Menlo Park
# 6              Menlo Park
# 7              Menlo Park
# 8            Redwood City
# 9            Redwood City
# 10           Redwood City
# 11           Redwood City
# 12           Redwood City
# 13           Redwood City
# 14          San Francisco
# 15              Sunnyvale
# 16    South San Francisco
# 17           Redwood City
# 18              San Mateo
# 19                Belmont
# 20          San Francisco
# Name: city, dtype: object

# %%
type(data["city"])#second data type in pandas is series
# Out:
# pandas.core.series.Series

# %%
data2 = pd.read_excel("arline.xls.xlsx")# this function extract data from exl

# %%
data2
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
data1 = pd.read_excel("arline.xls.xlsx",sheet_name="Sheet2")

# %%
data1#we can find dada from many sheets by giving sheet name
# Out:
#     YEAR         Y         W          R         L         K
# 0   1948  1948.000  1948.000  1948.0000  1948.000  1948.000
# 1   1949     1.354     0.260     0.2181     1.384     0.559
# 2   1950     1.569     0.278     0.3157     1.388     0.573
# 3   1951     1.948     0.297     0.3940     1.550     0.564
# 4   1952     2.265     0.310     0.3559     1.802     0.574
# 5   1953     2.731     0.322     0.3593     1.926     0.711
# 6   1954     3.025     0.335     0.4025     1.964     0.776
# 7   1955     3.562     0.350     0.3961     2.116     0.827
# 8   1956     3.979     0.361     0.3822     2.435     0.800
# 9   1957     4.420     0.379     0.3045     2.707     0.921
# 10  1958     4.563     0.391     0.3284     2.706     1.067

# %%
data2 = pd.read_csv("glass.data", header=None,names=['A','B','C','D','E','F','G','H','I','J','K'])

# %%
data2# header function give header to data AND NAME can give column name and change name
# Out:
#        A        B      C     D     E      F     G     H     I    J  K
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0  1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0  1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0  1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0  1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0  1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ... ..
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0  7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0  7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0  7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0  7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0  7
#
# [214 rows x 11 columns]

# %%
data2.to_csv("test.csv",index=False)# this function can save your file in your system

# %%
data2.head(2)
# Out:
#    A        B      C     D     E      F     G     H    I    J  K
# 0  1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0  1
# 1  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0  1

# %%
data2.tail(2)
# Out:
#        A        B      C    D     E      F    G     H     I    J  K
# 212  213  1.51651  14.38  0.0  1.94  73.61  0.0  8.48  1.57  0.0  7
# 213  214  1.51711  14.23  0.0  2.08  73.36  0.0  8.62  1.67  0.0  7

# %%
data2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K'], dtype='object')

# %%
list(data2.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']

# %%
data2[['B','K']].head(2)
# Out:
#          B  K
# 0  1.52101  1
# 1  1.51761  1

# %%
data3 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data3.head(3)#we can also use raw data giving link
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data3.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
data4 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
data4#this function fetch the data frm htmllink
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(data4)
# Out:
# list

# %%
len(data4)
# Out:
# 1

# %%
data4[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
data4[0].to_csv("players.csv",index=False)

# %%
type(data4[0])
# Out:
# pandas.core.frame.DataFrame

# %%
len(data4[0])
# Out:
# 675

# %%
list(data4[0])
# Out:
# ['Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
data5 = pd.read_csv("contacts.csv")

# %%
data5.head()
# Out:
#    id  location_id  organization_id  service_id                name  \
# 0   1          1.0              NaN         NaN       Susan Houston
# 1   2          1.0              NaN         NaN  Christina Gonzalez
# 2   3          2.0              NaN         NaN        Brenda Brown
# 3   4          3.0              NaN         NaN  Howard Lader, LCSW
# 4   5          4.0              NaN         NaN  Kimberly Pesavento
#
#                               title email department
# 0  Director of Older Adult Services   NaN        NaN
# 1                   Center Director   NaN        NaN
# 2  Director, Second Career Services   NaN        NaN
# 3   Manager, Senior Peer Counseling   NaN        NaN
# 4            Director of Visitation   NaN        NaN

# %%
data6 = pd.read_html("https://www.bbc.com/sport/cricket/world-cup/table")

# %%
data6[0].to_csv("cricket.csv",index=False)

# %%
data7 = pd.read_csv(r"C:\Users\yash mohite\Downloads\iris.data",header=None,names=['patle_length','patle_width','saple_length','saple_width','type_flower'])

# %%
data7.to_csv("iris.csv",index=False)
