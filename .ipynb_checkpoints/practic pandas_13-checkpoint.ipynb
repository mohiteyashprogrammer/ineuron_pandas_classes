# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline

# %%
data = pd.read_csv("cleaned_dataset.csv")

# %%
data
# Out:
#             Country  Year      PM2.5       PM10  TotalDeaths   PMDeaths  \
# 0           Albania  2015  21.790000  32.415000    42.299773  21.786089
# 1           Albania  2016  21.480000  32.385000    41.018788  20.810664
# 2         Argentina  2015  10.260000  27.870000    33.086924  29.159094
# 3         Australia  2010   8.040000  15.323333    13.571713  13.140380
# 4         Australia  2011   7.316667  14.443333    13.727626  13.276676
# ..              ...   ...        ...        ...          ...        ...
# 328  United Kingdom  2014  11.708857  16.533143    18.084411  16.384936
# 329  United Kingdom  2015   9.711026  15.436154    18.243927  16.509079
# 330  United Kingdom  2016  10.245143  16.430857    17.891337  16.145949
# 331  United Kingdom  2017   9.039737  14.872105    17.783700  16.047669
# 332         Uruguay  2014   8.000000  25.830000    21.222999  18.554957
#
#      CitiesCount
# 0              2
# 1              2
# 2              1
# 3              3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      333 non-null    object
#  1   Year         333 non-null    int64
#  2   PM2.5        333 non-null    float64
#  3   PM10         333 non-null    float64
#  4   TotalDeaths  333 non-null    float64
#  5   PMDeaths     333 non-null    float64
#  6   CitiesCount  333 non-null    int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 18.3+ KB

# %%
data.dtypes
# Out:
# Country         object
# Year             int64
# PM2.5          float64
# PM10           float64
# TotalDeaths    float64
# PMDeaths       float64
# CitiesCount      int64
# dtype: object

# %%
list(data.columns)
# Out:
# ['Country', 'Year', 'PM2.5', 'PM10', 'TotalDeaths', 'PMDeaths', 'CitiesCount']

# %%
data.describe()
# Out:
#               Year       PM2.5        PM10  TotalDeaths    PMDeaths  \
# count   333.000000  333.000000  333.000000   333.000000  333.000000
# mean   2014.180180   23.141074   45.414597    39.023378   26.177802
# std       2.196101   21.263261   46.694763    31.218198   14.313898
# min    2010.000000    4.578462    6.030000     8.401696    7.544358
# 25%    2013.000000   11.256667   19.126667    18.114643   16.033366
# 50%    2014.000000   16.460000   27.862500    28.047017   22.430605
# 75%    2016.000000   25.000000   51.300000    46.775579   33.505289
# max    2017.000000  132.000000  395.333333   160.587443   73.723273
#
#        CitiesCount
# count   333.000000
# mean     16.471471
# std      29.233531
# min       1.000000
# 25%       2.000000
# 50%       5.000000
# 75%      14.000000
# max     197.000000

# %%
data.isnull().sum()
# Out:
# Country        0
# Year           0
# PM2.5          0
# PM10           0
# TotalDeaths    0
# PMDeaths       0
# CitiesCount    0
# dtype: int64

# %%
data[data["Country"] == "United Kingdom"]
# Out:
#             Country  Year      PM2.5       PM10  TotalDeaths   PMDeaths  \
# 326  United Kingdom  2010  12.459375  18.249688    21.117271  19.346020
# 327  United Kingdom  2013  12.355455  17.821515    19.289088  17.558559
# 328  United Kingdom  2014  11.708857  16.533143    18.084411  16.384936
# 329  United Kingdom  2015   9.711026  15.436154    18.243927  16.509079
# 330  United Kingdom  2016  10.245143  16.430857    17.891337  16.145949
# 331  United Kingdom  2017   9.039737  14.872105    17.783700  16.047669
#
#      CitiesCount
# 326           32
# 327           33
# 328           35
# 329           39
# 330           35
# 331           38

# %%
data[data["TotalDeaths"] > 100]
# Out:
#          Country  Year       PM2.5        PM10  TotalDeaths   PMDeaths  \
# 18    Bangladesh  2010   92.650000  173.400000   139.486259  48.081277
# 19    Bangladesh  2011  101.475000  139.250000   131.274601  46.173865
# 20    Bangladesh  2012  100.975000  168.050000   123.997147  45.078774
# 21    Bangladesh  2013   76.247500  129.347500   118.843062  42.282874
# 22    Bangladesh  2014   75.161250  143.512500   117.293263  44.117452
# 23    Bangladesh  2015   78.167143  129.007143   113.296744  43.270291
# 24    Bangladesh  2016   69.590000  124.472000   109.404043  40.632332
# 25    Bangladesh  2017   50.251111  126.704444   108.525478  41.485379
# 47      Cameroon  2012   82.666667  103.666667   133.527367  49.116232
# 145        India  2016   39.129437   85.146197   134.643938  70.131953
# 146        India  2017   39.044286   87.581319   131.994019  70.803435
# 189   Madagascar  2015    8.000000   13.000000   160.587443  16.518632
# ...

# %%
data[data["Country"] == "India"]
# Out:
#     Country  Year      PM2.5       PM10  TotalDeaths   PMDeaths  CitiesCount
# 145   India  2016  39.129437  85.146197   134.643938  70.131953           71
# 146   India  2017  39.044286  87.581319   131.994019  70.803435           91

# %%
data.corr()
# Out:
#                  Year     PM2.5      PM10  TotalDeaths  PMDeaths  CitiesCount
# Year         1.000000 -0.102785 -0.104572    -0.018391 -0.028018     0.118498
# PM2.5       -0.102785  1.000000  0.865415     0.741049  0.632443    -0.165271
# PM10        -0.104572  0.865415  1.000000     0.729155  0.622188    -0.198309
# TotalDeaths -0.018391  0.741049  0.729155     1.000000  0.745864    -0.215496
# PMDeaths    -0.028018  0.632443  0.622188     0.745864  1.000000    -0.200916
# CitiesCount  0.118498 -0.165271 -0.198309    -0.215496 -0.200916     1.000000

# %%
sns.relplot(x="TotalDeaths",y="PMDeaths",data=data)

# %%
sns.relplot(x="CitiesCount",y="TotalDeaths",data=data)

# %%
data.head()
# Out:
#      Country  Year      PM2.5       PM10  TotalDeaths   PMDeaths  CitiesCount
# 0    Albania  2015  21.790000  32.415000    42.299773  21.786089            2
# 1    Albania  2016  21.480000  32.385000    41.018788  20.810664            2
# 2  Argentina  2015  10.260000  27.870000    33.086924  29.159094            1
# 3  Australia  2010   8.040000  15.323333    13.571713  13.140380            3
# 4  Australia  2011   7.316667  14.443333    13.727626  13.276676            3

# %%
data.iloc[1]
# Out:
# Country          Albania
# Year                2016
# PM2.5              21.48
# PM10              32.385
# TotalDeaths    41.018788
# PMDeaths       20.810664
# CitiesCount            2
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# Country          Albania
# Year                2016
# PM2.5              21.48
# PM10              32.385
# TotalDeaths    41.018788
# PMDeaths       20.810664
# CitiesCount            2
# Name: 1, dtype: object

# %%
data.loc[3:6,["Country","TotalDeaths"]]
# Out:
#      Country  TotalDeaths
# 3  Australia    13.571713
# 4  Australia    13.727626
# 5  Australia    12.659725
# 6  Australia    11.874490

# %%
data.loc[[1,100],["Country","TotalDeaths"]]
# Out:
#      Country  TotalDeaths
# 1    Albania    41.018788
# 100  Ecuador    27.553637

# %%
data.iloc[8:10,[1,2]]
# Out:
#    Year     PM2.5
# 8  2015  7.078421
# 9  2016  6.742632

# %%
data.iloc[[1,300],[1,3]]
# Out:
#      Year    PM10
# 1    2016  32.385
# 300  2012  28.545

# %%
data.sample(10)
# Out:
#         Country  Year      PM2.5        PM10  TotalDeaths   PMDeaths  \
# 187  Luxembourg  2016  11.103333   20.113333    16.093345  13.948161
# 145       India  2016  39.129437   85.146197   134.643938  70.131953
# 255    Portugal  2010   8.364286   20.925714    21.071696  17.591197
# 279   Singapore  2014  18.000000   30.000000    20.394963  19.742903
# 213       Nepal  2016  42.000000   64.170000   134.878941  63.782491
# 74      Croatia  2016  12.027143   18.934286    34.235026  27.127956
# 112     Finland  2016   5.871538   12.231538     8.401696   7.544358
# 17      Bahrain  2012  57.897500  267.430000    69.802188  66.772119
# 75      Croatia  2017  11.787143   16.845714    33.552075  26.803493
# 184  Luxembourg  2013  16.360000   17.080000    18.009002  15.823012
#
#      CitiesCount
# 187            3
# 145           71
# 255           14
# 279            1
# 213            1
# 74             7
# 112           13
# 17             4
# 75             7
# 184            2

# %%
data.iloc[0:11,[1,2,3,4]]
