# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset('exercise')

# %%
data.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
data.tail()
# Out:
#     id    diet  pulse    time     kind
# 85  29  no fat    135  15 min  running
# 86  29  no fat    130  30 min  running
# 87  30  no fat     99   1 min  running
# 88  30  no fat    111  15 min  running
# 89  30  no fat    150  30 min  running

# %%
data.dtypes
# Out:
# id          int64
# diet     category
# pulse       int64
# time     category
# kind     category
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      90 non-null     int64
#  1   diet    90 non-null     category
#  2   pulse   90 non-null     int64
#  3   time    90 non-null     category
#  4   kind    90 non-null     category
# dtypes: category(3), int64(2)
# memory usage: 2.2 KB

# %%
data.describe()
# Out:
#               id       pulse
# count  90.000000   90.000000
# mean   15.500000   99.700000
# std     8.703932   14.858471
# min     1.000000   80.000000
# 25%     8.000000   90.250000
# 50%    15.500000   96.000000
# 75%    23.000000  103.000000
# max    30.000000  150.000000

# %%
data[data.dtypes[data.dtypes == "category"].index].describe()
# Out:
#           diet   time  kind
# count       90     90    90
# unique       2      3     3
# top     no fat  1 min  rest
# freq        45     30    30

# %%
# how many are resting
len(data[data["kind"] == "rest"])
# Out:
# 30

# %%
# how many are running
len(data[data["kind"] == "running"])
# Out:
# 30

# %%
len(data[data["kind"] == "walking"])
# Out:
# 30

# %%
# who follow the no fat diet
len(data[data["diet"] == "no fat"])
# Out:
# 45

# %%
# how many are on low fat diet
len(data[data["diet"] == "low fat"])
# Out:
# 45

# %%
len(data[(data["kind"] == "rest") & (data["diet"] == "no fat")])
# Out:
# 15

# %%
len(data[(data["kind"] == "running") & (data["diet"] == "low fat")])
# Out:
# 15

# %%
data.head()
# Out:
#    id     diet  pulse    time  kind
# 0   1  low fat     85   1 min  rest
# 1   1  low fat     85  15 min  rest
# 2   1  low fat     88  30 min  rest
# 3   2  low fat     90   1 min  rest
# 4   2  low fat     92  15 min  rest

# %%
len(data[data["time"] == max(data["time"])])
# Out:
# 30

# %%
data[data["pulse"] == max(data["pulse"])]
# Out:
#     id    diet  pulse    time     kind
# 89  30  no fat    150  30 min  running

# %%
data[data["pulse"] == min(data["pulse"])]
# Out:
#    id     diet  pulse   time  kind
# 9   4  low fat     80  1 min  rest

# %%
data["new"] = data["id"] * data["pulse"]

# %%
data.head()
# Out:
#    id     diet  pulse    time  kind  new
# 0   1  low fat     85   1 min  rest   85
# 1   1  low fat     85  15 min  rest   85
# 2   1  low fat     88  30 min  rest   88
# 3   2  low fat     90   1 min  rest  180
# 4   2  low fat     92  15 min  rest  184

# %%
def grp(x):
    if x == "rest":
        return "Fucker"
    else:
        return "Grate Job"

# %%
data["grp"] = data["kind"].apply(grp)

# %%
data.head()
# Out:
#    id     diet  pulse    time  kind  new     grp
# 0   1  low fat     85   1 min  rest   85  Fucker
# 1   1  low fat     85  15 min  rest   85  Fucker
# 2   1  low fat     88  30 min  rest   88  Fucker
# 3   2  low fat     90   1 min  rest  180  Fucker
# 4   2  low fat     92  15 min  rest  184  Fucker

# %%
data.drop("grp",axis=1,inplace=True)

# %%
data.drop(2)
# Out:
#     id     diet  pulse    time     kind   new
# 0    1  low fat     85   1 min     rest    85
# 1    1  low fat     85  15 min     rest    85
# 3    2  low fat     90   1 min     rest   180
# 4    2  low fat     92  15 min     rest   184
# 5    2  low fat     93  30 min     rest   186
# ..  ..      ...    ...     ...      ...   ...
# 85  29   no fat    135  15 min  running  3915
# 86  29   no fat    130  30 min  running  3770
# 87  30   no fat     99   1 min  running  2970
# 88  30   no fat    111  15 min  running  3330
# 89  30   no fat    150  30 min  running  4500
#
# [89 rows x 6 columns]

# %%
data.iloc[2]
# Out:
# id             1
# diet     low fat
# pulse         88
# time      30 min
# kind        rest
# new           88
# Name: 2, dtype: object

# %%
data.loc[2]
# Out:
# id             1
# diet     low fat
# pulse         88
# time      30 min
# kind        rest
# new           88
# Name: 2, dtype: object

# %%
data.loc[2:6]
# Out:
#    id     diet  pulse    time  kind  new
# 2   1  low fat     88  30 min  rest   88
# 3   2  low fat     90   1 min  rest  180
# 4   2  low fat     92  15 min  rest  184
# 5   2  low fat     93  30 min  rest  186
# 6   3  low fat     97   1 min  rest  291

# %%
data.loc[80:83,("time","new")]
# Out:
#       time   new
# 80  30 min  3780
# 81   1 min  2884
# 82  15 min  3472
# 83  30 min  3920

# %%
data.loc[[1,80],["id","kind"]]
# Out:
#     id     kind
# 1    1     rest
# 80  27  running

# %%
df = data.iloc[1:10]

# %%
df1 = pd.DataFrame(np.random.randint(1,20,(10,6)),columns= ["A","B","C","D","E","F"])

# %%
df1
# Out:
#     A   B   C   D   E   F
# 0   5  19   1  13   2  13
# 1  18   6   8   8   5   7
# 2   4  15  10  16  18   7
# 3   3   2   8  13   9  14
# 4   8  15  11   6   8  11
# 5  16  13  16  15   8   6
# 6   3  16  17  16   1  19
# 7  14  16   3  18  19   4
# 8   1  11   8  17   5   8
# 9  13  13   9   2  10  16

# %%
df
# Out:
#    id     diet  pulse    time  kind  new
# 1   1  low fat     85  15 min  rest   85
# 2   1  low fat     88  30 min  rest   88
# 3   2  low fat     90   1 min  rest  180
# 4   2  low fat     92  15 min  rest  184
# 5   2  low fat     93  30 min  rest  186
# 6   3  low fat     97   1 min  rest  291
# 7   3  low fat     97  15 min  rest  291
# 8   3  low fat     94  30 min  rest  282
# 9   4  low fat     80   1 min  rest  320

# %%
pd.concat([df,df1])
# Out:
#     id     diet  pulse    time  kind    new     A     B     C     D     E  \
# 1  1.0  low fat   85.0  15 min  rest   85.0   NaN   NaN   NaN   NaN   NaN
# 2  1.0  low fat   88.0  30 min  rest   88.0   NaN   NaN   NaN   NaN   NaN
# 3  2.0  low fat   90.0   1 min  rest  180.0   NaN   NaN   NaN   NaN   NaN
# 4  2.0  low fat   92.0  15 min  rest  184.0   NaN   NaN   NaN   NaN   NaN
# 5  2.0  low fat   93.0  30 min  rest  186.0   NaN   NaN   NaN   NaN   NaN
# 6  3.0  low fat   97.0   1 min  rest  291.0   NaN   NaN   NaN   NaN   NaN
# 7  3.0  low fat   97.0  15 min  rest  291.0   NaN   NaN   NaN   NaN   NaN
# 8  3.0  low fat   94.0  30 min  rest  282.0   NaN   NaN   NaN   NaN   NaN
# 9  4.0  low fat   80.0   1 min  rest  320.0   NaN   NaN   NaN   NaN   NaN
# 0  NaN      NaN    NaN     NaN   NaN    NaN   5.0  19.0   1.0  13.0   2.0
# 1  NaN      NaN    NaN     NaN   NaN    NaN  18.0   6.0   8.0   8.0   5.0
# 2  NaN      NaN    NaN     NaN   NaN    NaN   4.0  15.0  10.0  16.0  18.0
# ...

# %%
pd.concat([df,df1],axis=1)
# Out:
#     id     diet  pulse    time  kind    new   A   B   C   D   E   F
# 1  1.0  low fat   85.0  15 min  rest   85.0  18   6   8   8   5   7
# 2  1.0  low fat   88.0  30 min  rest   88.0   4  15  10  16  18   7
# 3  2.0  low fat   90.0   1 min  rest  180.0   3   2   8  13   9  14
# 4  2.0  low fat   92.0  15 min  rest  184.0   8  15  11   6   8  11
# 5  2.0  low fat   93.0  30 min  rest  186.0  16  13  16  15   8   6
# 6  3.0  low fat   97.0   1 min  rest  291.0   3  16  17  16   1  19
# 7  3.0  low fat   97.0  15 min  rest  291.0  14  16   3  18  19   4
# 8  3.0  low fat   94.0  30 min  rest  282.0   1  11   8  17   5   8
# 9  4.0  low fat   80.0   1 min  rest  320.0  13  13   9   2  10  16
# 0  NaN      NaN    NaN     NaN   NaN    NaN   5  19   1  13   2  13

# %%
df.join(df1)
# Out:
#    id     diet  pulse    time  kind  new   A   B   C   D   E   F
# 1   1  low fat     85  15 min  rest   85  18   6   8   8   5   7
# 2   1  low fat     88  30 min  rest   88   4  15  10  16  18   7
# 3   2  low fat     90   1 min  rest  180   3   2   8  13   9  14
# 4   2  low fat     92  15 min  rest  184   8  15  11   6   8  11
# 5   2  low fat     93  30 min  rest  186  16  13  16  15   8   6
# 6   3  low fat     97   1 min  rest  291   3  16  17  16   1  19
# 7   3  low fat     97  15 min  rest  291  14  16   3  18  19   4
# 8   3  low fat     94  30 min  rest  282   1  11   8  17   5   8
# 9   4  low fat     80   1 min  rest  320  13  13   9   2  10  16

# %%
df.join(df1,how = "inner")
# Out:
#    id     diet  pulse    time  kind  new   A   B   C   D   E   F
# 1   1  low fat     85  15 min  rest   85  18   6   8   8   5   7
# 2   1  low fat     88  30 min  rest   88   4  15  10  16  18   7
# 3   2  low fat     90   1 min  rest  180   3   2   8  13   9  14
# 4   2  low fat     92  15 min  rest  184   8  15  11   6   8  11
# 5   2  low fat     93  30 min  rest  186  16  13  16  15   8   6
# 6   3  low fat     97   1 min  rest  291   3  16  17  16   1  19
# 7   3  low fat     97  15 min  rest  291  14  16   3  18  19   4
# 8   3  low fat     94  30 min  rest  282   1  11   8  17   5   8
# 9   4  low fat     80   1 min  rest  320  13  13   9   2  10  16

# %%
df.join(df1,how = "outer")
# Out:
#     id     diet  pulse    time  kind    new   A   B   C   D   E   F
# 0  NaN      NaN    NaN     NaN   NaN    NaN   5  19   1  13   2  13
# 1  1.0  low fat   85.0  15 min  rest   85.0  18   6   8   8   5   7
# 2  1.0  low fat   88.0  30 min  rest   88.0   4  15  10  16  18   7
# 3  2.0  low fat   90.0   1 min  rest  180.0   3   2   8  13   9  14
# 4  2.0  low fat   92.0  15 min  rest  184.0   8  15  11   6   8  11
# 5  2.0  low fat   93.0  30 min  rest  186.0  16  13  16  15   8   6
# 6  3.0  low fat   97.0   1 min  rest  291.0   3  16  17  16   1  19
# 7  3.0  low fat   97.0  15 min  rest  291.0  14  16   3  18  19   4
# 8  3.0  low fat   94.0  30 min  rest  282.0   1  11   8  17   5   8
# 9  4.0  low fat   80.0   1 min  rest  320.0  13  13   9   2  10  16

# %%
df.join(df1,how = "left")
# Out:
#    id     diet  pulse    time  kind  new   A   B   C   D   E   F
# 1   1  low fat     85  15 min  rest   85  18   6   8   8   5   7
# 2   1  low fat     88  30 min  rest   88   4  15  10  16  18   7
# 3   2  low fat     90   1 min  rest  180   3   2   8  13   9  14
# 4   2  low fat     92  15 min  rest  184   8  15  11   6   8  11
# 5   2  low fat     93  30 min  rest  186  16  13  16  15   8   6
# 6   3  low fat     97   1 min  rest  291   3  16  17  16   1  19
# 7   3  low fat     97  15 min  rest  291  14  16   3  18  19   4
# 8   3  low fat     94  30 min  rest  282   1  11   8  17   5   8
# 9   4  low fat     80   1 min  rest  320  13  13   9   2  10  16

# %%
df.join(df1,how = "right")
# Out:
#     id     diet  pulse    time  kind    new   A   B   C   D   E   F
# 0  NaN      NaN    NaN     NaN   NaN    NaN   5  19   1  13   2  13
# 1  1.0  low fat   85.0  15 min  rest   85.0  18   6   8   8   5   7
# 2  1.0  low fat   88.0  30 min  rest   88.0   4  15  10  16  18   7
# 3  2.0  low fat   90.0   1 min  rest  180.0   3   2   8  13   9  14
# 4  2.0  low fat   92.0  15 min  rest  184.0   8  15  11   6   8  11
# 5  2.0  low fat   93.0  30 min  rest  186.0  16  13  16  15   8   6
# 6  3.0  low fat   97.0   1 min  rest  291.0   3  16  17  16   1  19
# 7  3.0  low fat   97.0  15 min  rest  291.0  14  16   3  18  19   4
# 8  3.0  low fat   94.0  30 min  rest  282.0   1  11   8  17   5   8
# 9  4.0  low fat   80.0   1 min  rest  320.0  13  13   9   2  10  16
